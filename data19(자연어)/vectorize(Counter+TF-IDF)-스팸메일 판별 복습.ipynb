# %%
from sklearn.feature_extraction.text import *
##CountVectorizer,TfidfVectorizer 사용, 특성추출
#CountVectorizer : 각 텍스트에서 단어 출현 횟수를 카운팅한 벡터
#TfidfVectorizer : TF-IDF라는 값을 사용하여 CountVectorizer의 단점을 보완함
#                   빈도수와 역빈도수를 함께 고려
import warnings
warnings.filterwarnings(action='ignore')
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
spam_df = pd.read_csv('./spamData/spam.csv', encoding='latin1')

# %%
spam_df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# ### extraction!(reg) => not null, word

# %%
#결측치를 빼보자.
spam_df = spam_df[spam_df['v2'].notnull()]
spam_df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#필요없는 컬럼을 지워보자.
spam_df.drop(columns=['Unnamed: 2','Unnamed: 3','Unnamed: 4'],
             inplace=True)

# %%
#중복값 제거
spam_df.drop_duplicates(subset=['v2'],inplace=True)
spam_df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
#정규식을 사용해서 영어제외 전부 없애보자.(특수문자 등)


spam_df['v2'] = spam_df['v2'].apply(lambda x: re.sub(r'[^a-zA-Z]+'," ",x))
spam_df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point crazy Available only in ...
# 1   ham                           Ok lar Joking wif u oni
# 2  spam  Free entry in a wkly comp to win FA Cup final ...
# 3   ham       U dun say so early hor U c already then say
# 4   ham  Nah I don t think he goes to usf he lives arou...

# %% [markdown]
# ### classification => train/test data

# %%
#test,train데이터를 나누어보자.

# %%
X_train, X_test, y_train, y_test = train_test_split(spam_df.iloc[:,1],#문제v2 
                                                    spam_df.iloc[:,0],#정답v1 
                                                    test_size=0.4, 
                                                    random_state=42)

# %%
print('X_train: ',X_train.shape, 'y_train: ',y_train.shape, 'X_test: ',X_test.shape,'y_test: ',y_test.shape)
# Out:
# X_train:  (3101,) y_train:  (3101,) X_test:  (2068,) y_test:  (2068,)

# %% [markdown]
# ### stopwords & vectorize => choice(Counter, Tf-idf) : fit(train) —> transform(train,test)

# %%
tfidf = TfidfVectorizer(min_df=5,
                       lowercase=True,
                       stop_words='english')

# %%
#fit 시켜보자.
tfidf.fit(X_train)
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=5, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words='english', strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
#문제들을 transform해보자.
X_train = tfidf.transform(X_train)
X_test = tfidf.transform(X_test)

# %%
print(X_train.shape, X_test.shape)
# Out:
# (3101, 928) (2068, 928)

# %%
tfidf.inverse_transform(X_test)
# Out:
# [array(['download', 'did'], dtype='<U15'),
#  array(['wid', 'wat', 'wana', 'ur', 'swt', 'smile', 'red', 'plz', 'pass',
#         'orange', 'miss', 'luv', 'hot', 'face', 'dis', 'blue'],
#        dtype='<U15'),
#  array(['ok'], dtype='<U15'),
#  array(['later', 'ill', 'film'], dtype='<U15'),
#  array(['sorry', 'phone', 'ok', 'left', 'date'], dtype='<U15'),
#  array(['urgent', 'rate', 'prize', 'nd', 'national', 'mobile', 'contact',
#         'caller', 'bt', 'box', 'bonus', 'awarded', 'attempt'], dtype='<U15'),
#  array(['school', 'plus', 'offer', 'got'], dtype='<U15'),
#  array(['week', 'ringtone', 'new', 'mobile', 'gr', 'direct', 'club'],
#        dtype='<U15'),
#  array(['week', 'know', 'going', 'don', 'da'], dtype='<U15'),
#  array(['started', 'office', 'da'], dtype='<U15'),
#  array(['waiting', 'ur', 'test', 'tell', 'reply', 'number', 'lt', 'gt',
#         'face'], dtype='<U15'),
#  array(['set', 'big'], dtype='<U15'),
#  array(['wow', 'win', 'uk', 'txt', 'tickets', 'info', 'club', 'book'],
#        dtype='<U15'),
#  array(['shit', 'lt', 'like', 'gt', 'gonna', 'doin'], dtype='<U15'),
#  array(['pretty', 'man', 'make'], dtype='<U15'),
#  array(['gd'], dtype='<U15'),
#  array(['want', 'night'], dtype='<U15'),
#  array(['miss', 'know', 'double'], dtype='<U15'),
#  array(['think', 'talking', 'missing', 'love', 'good', 'doing', 'boy',
#         'babe'], dtype='<U15'),
#  array(['brother'], dtype='<U15'),
#  array(['wid', 'ur', 'play', 'music', 'mobile', 'mates', 'games',
#         'congrats'], dtype='<U15'),
#  array(['send', 'problem', 'prob', 'like', 'laptop', 'ill', 'ah'],
#        dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['time', 'text', 'taking', 'ready', 'll', 'leave', 'just', 'amp'],
#        dtype='<U15'),
#  array(['text'], dtype='<U15'),
#  array(['points', 'numbers', 'like', 'decimal'], dtype='<U15'),
#  array(['yo', 'tho', 'real', 'play', 'mr', 'just', 'feel'], dtype='<U15'),
#  array(['later'], dtype='<U15'),
#  array(['urgent', 'thats', 'prob', 'lt', 'gt', 'dis', 'car', 'buy'],
#        dtype='<U15'),
#  array(['office', 'na'], dtype='<U15'),
#  array(['yes', 'secret'], dtype='<U15'),
#  array(['late', 'goin'], dtype='<U15'),
#  array(['ur', 'prize', 'mobile', 'details', 'claim'], dtype='<U15'),
#  array(['noon', 'lucky', 'actually'], dtype='<U15'),
#  array(['way', 'thought', 'number', 'haven', 'don', 'ask', 'alex'],
#        dtype='<U15'),
#  array(['voucher', 'unsubscribe', 'text', 'stop', 'gift', 'draw'],
#        dtype='<U15'),
#  array(['www', 'txt', 'today', 'tc', 'optout', 'nokia', 'new', 'gbp',
#         'collect'], dtype='<U15'),
#  array(['www', 'word', 'win', 'weekly', 'uk', 'text', 'just', 'free',
#         'entry'], dtype='<U15'),
#  array(['ur', 'thk', 'sounds', 'second', 'msg', 'll', 'gee', 'enjoy',
#         'den'], dtype='<U15'),
#  array(['send'], dtype='<U15'),
#  array(['thinks', 'stop', 'special', 'secret', 'reply', 'opt', 'msg',
#         'care'], dtype='<U15'),
#  array(['xxx', 'wanna', 'tonight', 'tomorrow', 'sorry', 'really', 'love',
#         'im', 'hi', 'bed', 'babe'], dtype='<U15'),
#  array(['want', 'somebody', 'just', 'come'], dtype='<U15'),
#  array(['leaving', 'guys'], dtype='<U15'),
#  array(['run', 'da'], dtype='<U15'),
#  array(['sir', 'plz', 'morning', 'good'], dtype='<U15'),
#  array(['yup', 'today', 'time', 'thanx', 'sun', 'mths', 'll', 'hope',
#         'haf', 'going', 'finish', 'dinner', 'coming', 'come'], dtype='<U15'),
#  array(['plz', 'lt', 'chance'], dtype='<U15'),
#  array(['today', 'office', 'morning', 'im', 'good', 'come', 'able'],
#        dtype='<U15'),
#  array(['wat', 'thk', 'sun', 'sat', 'nt', 'lor', 'lesson', 'juz', 'hey',
#         'cos'], dtype='<U15'),
#  array(['ugh', 'dont'], dtype='<U15'),
#  array(['yeah', 'understand', 'sounds', 'ring', 'love', 'later',
#         'important', 'darlin', 'baby'], dtype='<U15'),
#  array(['love', 'fucking', 'deep'], dtype='<U15'),
#  array(['time', 'somebody', 'remember', 'got', 'awesome'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['hey', 'free'], dtype='<U15'),
#  array(['waiting', 'ur', 'tv', 'start', 'lor', 'leh', 'doing', 'busy'],
#        dtype='<U15'),
#  array(['wat', 'log'], dtype='<U15'),
#  array(['eating', 'confirm'], dtype='<U15'),
#  array(['yesterday', 'wonderful', 'thanks', 'sir', 'hope'], dtype='<U15'),
#  array(['funny'], dtype='<U15'),
#  array(['want', 'just', 'home', 'don', 'come'], dtype='<U15'),
#  array(['tell', 'say', 'ok', 'need', 'like', 'happen', 'dont'],
#        dtype='<U15'),
#  array(['txt', 'tired', 'ring', 'quite', 'pete', 'meet', 'love', 'hey',
#         'hav', 'got', 'fancy'], dtype='<U15'),
#  array(['shit', 'seeing', 'oh', 'actually'], dtype='<U15'),
#  array(['ur', 'abt'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['win', 'reply', 'free', 'chance'], dtype='<U15'),
#  array(['tones', 'text', 'pass', 'enjoy', 'collect', 'apply'], dtype='<U15'),
#  array(['wow', 'thk', 'old', 'lor', 'll', 'later', 'dog'], dtype='<U15'),
#  array(['want', 'buy'], dtype='<U15'),
#  array(['wk', 'weekly', 'tones', 'service', 'gr', 'enjoy', 'credit',
#         'choose'], dtype='<U15'),
#  array(['way', 'office', 'da'], dtype='<U15'),
#  array(['xxx', 'way', 'really', 'missing', 'just', 'im', 'hi', 'darlin',
#         'big'], dtype='<U15'),
#  array(['write', 'wat'], dtype='<U15'),
#  array(['ok'], dtype='<U15'),
#  array(['prize', 'mob', 'customer', 'bonus', 'awarded'], dtype='<U15'),
#  array(['wat', 'wan', 'time', 'lor', 'look', 'come'], dtype='<U15'),
#  array(['reply', 'office', 'morning', 'lt', 'll', 'ill', 'home', 'gt',
#         'decimal', 'coming', 'came'], dtype='<U15'),
#  array(['xx', 'won', 'wc', 'urgent', 'nd', 'max', 'contact', 'attempt'],
#        dtype='<U15'),
#  array(['tell', 'quite', 'long', 'haven', 'finish', 'film', 'cos'],
#        dtype='<U15'),
#  array(['project', 'ok', 'meeting', 'lor', 'having', 'early'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['urgent', 'pls', 'hello', 'download'], dtype='<U15'),
#  array(['think', 'say', 'person', 'need', 'live', 'life', 'fantastic',
#         'die', 'did', 'chance'], dtype='<U15'),
#  array(['words', 'dear'], dtype='<U15'),
#  array(['place', 'going', 'dear'], dtype='<U15'),
#  array(['spend'], dtype='<U15'),
#  array(['life'], dtype='<U15'),
#  array(['ur', 'txt', 'tone', 'tell', 'song', 'poly', 'need', 'moon', 'mob'],
#        dtype='<U15'),
#  array(['yes', 'trying', 'come'], dtype='<U15'),
#  array(['got', 'dude'], dtype='<U15'),
#  array(['sir', 'goodmorning', 'free'], dtype='<U15'),
#  array(['won', 'tried', 'time', 'rate', 'prize', 'pound', 'nd', 'national',
#         'minute', 'easy', 'contact', 'claim', 'bt'], dtype='<U15'),
#  array(['txt', 'true', 'tones', 'tone', 'text', 'stop', 'st', 'ringtone',
#         'poly', 'nd', 'help', 'free'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['wil', 'want', 'time', 'say', 'got', 'didnt', 'dear'], dtype='<U15'),
#  array(['wan', 'rest', 'project', 'meet', 'going', 'da'], dtype='<U15'),
#  array(['okie'], dtype='<U15'),
#  array(['usf', 'tonight', 'know', 'hey', 'half', 'guy', 'able'],
#        dtype='<U15'),
#  array(['trip', 'today', 'taking', 'quite', 'project', 'ok', 'lor', 'jus',
#         'final', 'cos'], dtype='<U15'),
#  array(['update', 'mths', 'mobile', 'latest', 'free', 'colour', 'camera'],
#        dtype='<U15'),
#  array(['lunch', 'eat'], dtype='<U15'),
#  array(['took', 'sorry', 'long'], dtype='<U15'),
#  array(['ur', 'smth', 'lunch', 'lor', 'finish', 'ard', 'aft'], dtype='<U15'),
#  array(['tomorrow', 'thats', 'sleep', 'oh', 'night', 'late', 'good',
#         'going'], dtype='<U15'),
#  array(['just', 'did'], dtype='<U15'),
#  array(['trying', 'sure', 'soon', 'need', 'll', 'just'], dtype='<U15'),
#  array(['statement', 'shows', 'redeemed', 'private', 'points',
#         'identifier', 'expires', 'code', 'account'], dtype='<U15'),
#  array(['world', 'wonderful', 'sunday', 'smile', 'person', 'makes',
#         'goodmorning', 'feel', 'amp'], dtype='<U15'),
#  array(['soon', 'ones', 'liked', 'like', 'heart'], dtype='<U15'),
#  array(['love'], dtype='<U15'),
#  array(['online', 'need', 'job', 'details'], dtype='<U15'),
#  array(['said', 'right', 'pa', 'doctor'], dtype='<U15'),
#  array(['year', 'text', 'send', 'really', 'number', 'new', 'miss', 'just',
#         'happy', 'happiness', 'got', 'decided', 'dear', 'brother',
#         'abiola'], dtype='<U15'),
#  array(['things', 'hope', 'great', 'going', 'fine', 'day', 'coming',
#         'busy'], dtype='<U15'),
#  array(['want', 'send', 'net', 'need', 'money', 'miss', 'let', 'know',
#         'fuck', 'crave', 'babe'], dtype='<U15'),
#  array(['www', 'weeks', 'voucher', 'uk', 'ts', 'text', 'pc', 'offer',
#         'http', 'dear', 'cs', 'claim', 'apply'], dtype='<U15'),
#  array(['ve', 'open', 'like', 'got'], dtype='<U15'),
#  array(['work', 'sleep', 'saturday', 'late', 'evening', 'day'],
#        dtype='<U15'),
#  array(['www', 'want', 'waiting', 'time', 'read', 'guess', 'friend', 'com'],
#        dtype='<U15'),
#  array(['looking', 'job'], dtype='<U15'),
#  array(['wine', 'sleep', 'morning'], dtype='<U15'),
#  array(['txts', 'orange', 'optout', 'nokia', 'motorola', 'mobileupd',
#         'mins', 'latest', 'free', 'double'], dtype='<U15'),
#  array(['lt', 'gt', 'class'], dtype='<U15'),
#  array(['send'], dtype='<U15'),
#  array(['way', 'ur', 'person', 'night', 'make', 'love', 'happy', 'gud',
#         'friendship', 'friend', 'feel'], dtype='<U15'),
#  array(['yeah', 'got'], dtype='<U15'),
#  array(['like'], dtype='<U15'),
#  array(['new', 'game', 'ex', 'early', 'comin'], dtype='<U15'),
#  array(['ok', 'meeting', 'later'], dtype='<U15'),
#  array(['yo', 'like', 'hungry'], dtype='<U15'),
#  array(['doesn'], dtype='<U15'),
#  array(['watch', 've', 'told', 'today', 'thanx', 'really', 'like', 'gave',
#         'fr', 'face', 'dat', 'cos'], dtype='<U15'),
#  array(['prize', 'mob', 'customer', 'bonus', 'awarded'], dtype='<U15'),
#  array(['wake', 'think', 'slave', 'send', 'sea', 'new', 'lover', 'kiss',
#         'job', 'hello', 'happy', 'goes'], dtype='<U15'),
#  array(['wif', 'wat', 'thk', 'said', 'quite', 'pretty', 'look', 'long',
#         'leh', 'hair'], dtype='<U15'),
#  array(['ve', 'stay', 'selected', 'rate', 'national', 'holiday', 'claim'],
#        dtype='<U15'),
#  array(['today', 'time', 'supposed', 'shopping'], dtype='<U15'),
#  array(['wait', 'min', 'lt', 'gt', 'come'], dtype='<U15'),
#  array(['weekend', 'update', 'unlimited', 'mths', 'mobile', 'latest',
#         'free', 'colour', 'camera', 'calls'], dtype='<U15'),
#  array(['urgent', 'evening', 'da'], dtype='<U15'),
#  array(['shd', 'sch', 'lor', 'lei', 'hr', 'dunno', 'driving', 'cos'],
#        dtype='<U15'),
#  array(['week', 'ringtone', 'enjoy'], dtype='<U15'),
#  array(['right', 'come'], dtype='<U15'),
#  array(['hear', 'good'], dtype='<U15'),
#  array(['tv', 'talk', 'going', 'da'], dtype='<U15'),
#  array(['morning', 'good'], dtype='<U15'),
#  array(['like', 'called', 'actually'], dtype='<U15'),
#  array(['sir', 'need', 'bank', 'address', 'account'], dtype='<U15'),
#  array(['wish', 'mo', 'happy', 'enjoy', 'congratulations'], dtype='<U15'),
#  array(['waiting', 'ur', 'thk', 'sis', 'room', 'phone', 'network', 'need',
#         'liao', 'lar', 'jus', 'gd', 'finish', 'dunno', 'dun', 'card',
#         'bathe'], dtype='<U15'),
#  array(['fun'], dtype='<U15'),
#  array(['winner', 'speak', 'selected', 'receive', 'pm', 'operator', 'live',
#         'cost', 'claim', 'cash', 'award'], dtype='<U15'),
#  array(['thk', 'oso', 'meet', 'll', 'hmmm', 'em', 'dun', 'den'],
#        dtype='<U15'),
#  array(['nope'], dtype='<U15'),
#  array(['weed'], dtype='<U15'),
#  array(['worth', 'wanted', 'sorry', 'meant', 'lt', 'light', 'gt', 'friend'],
#        dtype='<U15'),
#  array(['wot', 'wont', 'text', 'tell', 'luv', 'just', 'im', 'home'],
#        dtype='<U15'),
#  array(['online'], dtype='<U15'),
#  array(['went', 'shop'], dtype='<U15'),
#  array(['online', 'like', 'hi', 'chat'], dtype='<U15'),
#  array(['leave', 'hi', 'did', 'asked'], dtype='<U15'),
#  array(['send', 'pls', 'da', 'correct'], dtype='<U15'),
#  array(['hey'], dtype='<U15'),
#  array(['able'], dtype='<U15'),
#  array(['yup', 'stop'], dtype='<U15'),
#  array(['yrs', 've', 'txt', 'suite', 'row', 'ldn', 'lands', 'invited',
#         'hl', 'final', 'dear', 'contact', 'chat', 'attempt'], dtype='<U15'),
#  array(['remember', 'old', 'don'], dtype='<U15'),
#  array(['xx', 'won', 'wc', 'ppm', 'nd', 'max', 'contact', 'attempt'],
#        dtype='<U15'),
#  array(['trip', 'safe', 'great', 'dont'], dtype='<U15'),
#  array(['thats', 'sure', 'supposed', 'pub', 'good', 'bit'], dtype='<U15'),
#  array(['just', 'great', 'doing', 'day', 'abiola'], dtype='<U15'),
#  array(['yes'], dtype='<U15'),
#  array(['test', 'isn', 'computer', 'address'], dtype='<U15'),
#  array(['yeah', 'work', 'thing', 'sure', 'night', 'll'], dtype='<U15'),
#  array(['time', 'tell', 'ill'], dtype='<U15'),
#  array(['used', 'nice', 'busy'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['time', 'sorry', 'seeing', 'say', 'gonna'], dtype='<U15'),
#  array(['ur', 'ni', 'love', 'life', 'gud', 'god'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['today', 'sis', 'need', 'lar', 'cos'], dtype='<U15'),
#  array(['winner', 'valid', 'selected', 'reward', 'prize', 'network',
#         'hours', 'customer', 'code', 'claim'], dtype='<U15'),
#  array(['online', 'nope', 'll', 'come'], dtype='<U15'),
#  array(['want', 'time', 'come', 'aight'], dtype='<U15'),
#  array(['think', 'place', 'far', 'check'], dtype='<U15'),
#  array(['yes', 'good'], dtype='<U15'),
#  array(['stay', 'll'], dtype='<U15'),
#  array(['ur', 'ass'], dtype='<U15'),
#  array(['yeah', 'mu', 'minutes', 'll', 'let', 'leave', 'know', 'couple',
#         'amp'], dtype='<U15'),
#  array(['winner', 'speak', 'selected', 'receive', 'pm', 'operator', 'live',
#         'cost', 'claim', 'cash', 'award'], dtype='<U15'),
#  array(['today', 'pls', 'birthday'], dtype='<U15'),
#  array(['pick', 'ok', 'evening'], dtype='<U15'),
#  array(['winner', 'speak', 'selected', 'receive', 'operator', 'live',
#         'holiday', 'claim', 'cash'], dtype='<U15'),
#  array(['messages', 'know', 'getting', 'dont'], dtype='<U15'),
#  array(['voucher', 'txt', 'gift', 'entered', 'draw', 'correct'],
#        dtype='<U15'),
#  array(['available'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['trust', 'lol'], dtype='<U15'),
#  array(['person', 'haha', 'gonna', 'ask'], dtype='<U15'),
#  array(['tell', 'smth', 'number', 'like', 'forgot'], dtype='<U15'),
#  array(['booked'], dtype='<U15'),
#  array(['yes', 'completely'], dtype='<U15'),
#  array(['ur', 'think', 'thanx', 'rite', 'love', 'day'], dtype='<U15'),
#  array(['leave'], dtype='<U15'),
#  array(['valentines', 'happy', 'day'], dtype='<U15'),
#  array(['yup', 'wif', 'tot', 'smth', 'sleeping', 'send', 'picking', 'mean',
#         'lor', 'liao', 'going', 'ard'], dtype='<U15'),
#  array(['wif', 'lei', 'laptop', 'da', 'card'], dtype='<U15'),
#  array(['listen', 'email', 'cost'], dtype='<U15'),
#  array(['think', 'saying', 'ok', 'need', 'leave', 'come', 'ask'],
#        dtype='<U15'),
#  array(['wait', 'lor'], dtype='<U15'),
#  array(['th', 'post', 'office', 'man', 'lt', 'house', 'holiday', 'gt',
#         'coz'], dtype='<U15'),
#  array(['www', 'wkly', 'wk', 'win', 'txt', 'nokia', 'latest', 'http',
#         'great', 'gr', 'free', 'entry', 'comp', 'com', 'chance', 'cash'],
#        dtype='<U15'),
#  array(['wq', 'week', 'ur', 'txt', 'tone', 'tell', 'st', 'pobox', 'nokia',
#         'mob', 'mates', 'just', 'free'], dtype='<U15'),
#  array(['ur', 'person', 'night', 'msg', 'make', 'love', 'know', 'hard',
#         'good', 'friendship', 'best', 'amp'], dtype='<U15'),
#  array(['work', 'remember', 'lol', 'like', 'feel', 'does'], dtype='<U15'),
#  array(['right', 'phone', 'calling'], dtype='<U15'),
#  array(['guess'], dtype='<U15'),
#  array(['great', 'day', 'beautiful'], dtype='<U15'),
#  array(['till', 'special', 'people', 'life', 'ends'], dtype='<U15'),
#  array(['smile', 'send', 'sea', 'make', 'kiss', 'job', 'hope', 'happy',
#         'fine', 'did', 'baby', 'alright'], dtype='<U15'),
#  array(['change'], dtype='<U15'),
#  array(['trying'], dtype='<U15'),
#  array(['yup', 'shd', 'haf', 'got', 'ard', 'add'], dtype='<U15'),
#  array(['txt', 'stop', 'reply', 'pounds', 'msg', 'maybe', 'free', 'claim'],
#        dtype='<U15'),
#  array(['xmas', 'won', 'valid', 'trying', 'todays', 'shows', 'prize',
#         'line', 'land', 'hrs', 'guaranteed', 'draw', 'contact'],
#        dtype='<U15'),
#  array(['week', 'want', 'video', 'reply', 'phone', 'new', 'network',
#         'mins', 'free', 'calls', 'anytime'], dtype='<U15'),
#  array(['thanx', 'ok'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['way', 'paying', 'ok', 'food'], dtype='<U15'),
#  array(['home', 'going', 'fr'], dtype='<U15'),
#  array(['wants', 'questions', 'fine'], dtype='<U15'),
#  array(['tomorrow', 'pick', 'mah', 'll'], dtype='<U15'),
#  array(['wasn', 'paying'], dtype='<U15'),
#  array(['ice', 'fine', 'age'], dtype='<U15'),
#  array(['week', 'good', 'double'], dtype='<U15'),
#  array(['works', 'work', 'tomorrow', 'meet', 'house', 'gets'], dtype='<U15'),
#  array(['think', 'smile', 'sleep', 'miss', 'loving', 'love', 'long',
#         'hope', 'hey', 'goes', 'did', 'day', 'babe'], dtype='<U15'),
#  array(['ur', 'reply', 'ok'], dtype='<U15'),
#  array(['like', 'depends'], dtype='<U15'),
#  array(['xxx', 'thanx', 'soon', 'nite', 'im', 'darlin', 'cool', 'care'],
#        dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['great'], dtype='<U15'),
#  array(['plan', 'don', 'da'], dtype='<U15'),
#  array(['stop', 'needs', 'make', 'going', 'fucking', 'bed'], dtype='<U15'),
#  array(['ve', 'sent'], dtype='<U15'),
#  array(['sorry', 'll', 'later'], dtype='<U15'),
#  array(['wish', 'today', 'rest', 'night', 'morning', 'luv', 'hope', 'good',
#         'evening', 'day', 'afternoon'], dtype='<U15'),
#  array(['ok', 'buy'], dtype='<U15'),
#  array(['www', 'unsubscribe', 'text', 'stop', 'pls', 'net', 'help', 'goto',
#         'extra', 'charge'], dtype='<U15'),
#  array(['win', 'means', 'india'], dtype='<U15'),
#  array(['sleep', 'ok', 'nite', 'lar', 'early'], dtype='<U15'),
#  array(['ok', 'neva', 'mind'], dtype='<U15'),
#  array(['home', 'em', 'box'], dtype='<U15'),
#  array(['went', 'oredi', 'dad'], dtype='<U15'),
#  array(['working', 'text', 'later', 'free', 'chat', 'bit'], dtype='<U15'),
#  array(['new'], dtype='<U15'),
#  array(['hi', 'happy', 'birthday'], dtype='<U15'),
#  array(['need'], dtype='<U15'),
#  array(['shall', 'house', 'bus'], dtype='<U15'),
#  array(['like', 'haf', 'got'], dtype='<U15'),
#  array(['year', 'went', 'told', 'today', 'think', 'telling', 'talk',
#         'place', 'number', 'morning', 'getting', 'come', 'car', 'actually'],
#        dtype='<U15'),
#  array(['video', 'unlimited', 'tried', 'text', 'reply', 'offer', 'mins',
#         'contact', 'camcorder', 'anytime'], dtype='<U15'),
#  array(['trying'], dtype='<U15'),
#  array(['worry', 'dont', 'called'], dtype='<U15'),
#  array(['stop', 'mins', 'lt', 'gt'], dtype='<U15'),
#  array(['ya'], dtype='<U15'),
#  array(['wat', 'ok', 'long', 'got'], dtype='<U15'),
#  array(['went', 'wat', 'tot', 'shopping', 'say', 'outside', 'nice', 'look',
#         'jus', 'darren', 'course', 'cos', 'come'], dtype='<U15'),
#  array(['wont', 'thing', 'don'], dtype='<U15'),
#  array(['win', 'txt', 'tv', 'quiz', 'does', 'chance', 'cash'], dtype='<U15'),
#  array(['number', 'got'], dtype='<U15'),
#  array(['message'], dtype='<U15'),
#  array(['shopping', 'leh', 'haha', 'eh', 'abt'], dtype='<U15'),
#  array(['xxx', 'txt', 'love', 'ive', 'hello', 'finished', 'finish',
#         'darlin', 'college'], dtype='<U15'),
#  array(['win', 'text', 'quiz'], dtype='<U15'),
#  array(['saw', 'message', 'just', 'da'], dtype='<U15'),
#  array(['way', 'swing', 'late', 'haha', 'better'], dtype='<U15'),
#  array(['mrng', 'gud', 'congrats'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['place'], dtype='<U15'),
#  array(['stuff', 'make', 'good'], dtype='<U15'),
#  array(['ok', 'did', 'dear'], dtype='<U15'),
#  array(['pounds', 'ok', 'hope', 'got'], dtype='<U15'),
#  array(['mrt', 'meet', 'lor', 'like', 'juz', 'haf', 'dun', 'dat', 'come',
#         'ard'], dtype='<U15'),
#  array(['www', 'voucher', 'stop', 'reply', 'opt', 'log', 'customer',
#         'credit', 'com', 'care'], dtype='<U15'),
#  array(['try', 'question', 'lt', 'hav', 'gt', 'answer'], dtype='<U15'),
#  array(['walk', 'place', 'meh', 'lor', 'got'], dtype='<U15'),
#  array(['guys'], dtype='<U15'),
#  array(['minutes', 'ill', 'fb', 'couple', 'aight'], dtype='<U15'),
#  array(['today', 'thing', 'started', 'nxt', 'good', 'did', 'birthday'],
#        dtype='<U15'),
#  array(['way', 'treat', 'today', 'thanks', 'special', 'shall', 'secret',
#         'real', 'dont', 'date', 'da'], dtype='<U15'),
#  array(['nite', 'love', 'im', 'hi', 'gonna', 'darlin', 'come'],
#        dtype='<U15'),
#  array(['town'], dtype='<U15'),
#  array(['tonight', 'text', 'll', 'aight'], dtype='<U15'),
#  array(['want'], dtype='<U15'),
#  array(['yeah', 'sorry'], dtype='<U15'),
#  array(['send', 'number', 'new'], dtype='<U15'),
#  array(['think', 'send', 'sea', 'love', 'kiss', 'goes', 'doing', 'day',
#         'babe'], dtype='<U15'),
#  array(['statement', 'shows', 'redeemed', 'private', 'points',
#         'identifier', 'expires', 'code', 'account'], dtype='<U15'),
#  array(['time', 'say', 'jus', 'dunno'], dtype='<U15'),
#  array(['yes', 'ur', 'office', 'da'], dtype='<U15'),
#  array(['today', 'thinking', 'send', 'missing', 'loving', 'loved', 'like',
#         'kiss', 'hello', 'boytoy'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['doing'], dtype='<U15'),
#  array(['watch', 'want', 'mean', 'come'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['want', 'meet'], dtype='<U15'),
#  array(['class'], dtype='<U15'),
#  array(['things', 'make'], dtype='<U15'),
#  array(['week', 'want', 'video', 'tomorrow', 'text', 'reply', 'pounds',
#         'phone', 'new', 'network', 'mins', 'delivery', 'anytime'],
#        dtype='<U15'),
#  array(['msg', 'comes'], dtype='<U15'),
#  array(['use', 'uk', 'sent', 'link', 'http'], dtype='<U15'),
#  array(['makes', 'half'], dtype='<U15'),
#  array(['years', 'wondering', 'things', 'sent', 'plan', 'pay', 'okay',
#         'nigeria', 'lt', 'like', 'let', 'know', 'gt'], dtype='<U15'),
#  array(['treat', 'congrats'], dtype='<U15'),
#  array(['oh', 'know', 'dont'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['come'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['oh', 'maybe', 'ill'], dtype='<U15'),
#  array(['tonight', 'really', 'babe'], dtype='<U15'),
#  array(['ur', 'today', 'sorry', 'plz', 'just', 'hurt', 'good', 'day',
#         'angry'], dtype='<U15'),
#  array(['know', 'called'], dtype='<U15'),
#  array(['want', 'pls', 'ones', 'nice', 'luv', 'lt', 'hey', 'help', 'gt',
#         'card'], dtype='<U15'),
#  array(['yeah', 'sound', 'leave', 'hour'], dtype='<U15'),
#  array(['think', 'sweet', 'send', 'sea', 'kiss', 'hope', 'happy', 'good',
#         'day', 'content', 'afternoon'], dtype='<U15'),
#  array(['ve', 'hey', 'half', 'got'], dtype='<U15'),
#  array(['took', 'say', 'pain', 'little', 'hours', 'hope', 'don', 'die'],
#        dtype='<U15'),
#  array(['type'], dtype='<U15'),
#  array(['means', 'door'], dtype='<U15'),
#  array(['tomorrow', 'tell', 'going', 'come'], dtype='<U15'),
#  array(['taking', 'class'], dtype='<U15'),
#  array(['guess', 'coffee'], dtype='<U15'),
#  array(['want', 'ur', 'uk', 'tonight', 'sent', 'real', 'nyt', 'network',
#         'msg', 'mob', 'join', 'direct'], dtype='<U15'),
#  array(['pray', 'night', 'just', 'family', 'away'], dtype='<U15'),
#  array(['know'], dtype='<U15'),
#  array(['ur', 'send', 'quiz', 'msg', 'cash', 'balance'], dtype='<U15'),
#  array(['thanks', 'just'], dtype='<U15'),
#  array(['shop', 'really', 'lot', 'good'], dtype='<U15'),
#  array(['need', 'minute', 'll', 'carlos', 'buy'], dtype='<U15'),
#  array(['want', 'price', 'lt', 'let', 'know', 'gt'], dtype='<U15'),
#  array(['wat', 'use', 'ur', 'tot', 'study', 'really', 'paper', 'long',
#         'lar', 'jus', 'happy', 'haf', 'got', 'ago'], dtype='<U15'),
#  array(['set', 'love', 'just', 'big'], dtype='<U15'),
#  array(['class'], dtype='<U15'),
#  array(['shopping', 'real', 'oh'], dtype='<U15'),
#  array(['waiting', 'text', 'stop', 'service', 'send', 'night', 'hi',
#         'great', 'girls'], dtype='<U15'),
#  array(['lar', 'juz', 'buy'], dtype='<U15'),
#  array(['wat', 'wait', 'ur', 'tot', 'sms', 'reply', 'neva', 'lar',
#         'havent', 'finish', 'cos'], dtype='<U15'),
#  array(['sorry', 'mistake', 'da'], dtype='<U15'),
#  array(['ya', 'wit', 'vl', 'ur', 'thanks', 'st', 'ok', 'knw', 'family',
#         'enjoy'], dtype='<U15'),
#  array(['tonight', 'mu', 'man', 'coming', 'carlos'], dtype='<U15'),
#  array(['ok', 'gym', 'free'], dtype='<U15'),
#  array(['xx', 'wen', 'ur', 'price', 'pick', 'okay', 'long', 'ave'],
#        dtype='<U15'),
#  array(['meeting', 'da'], dtype='<U15'),
#  array(['waiting', 'sir', 'free'], dtype='<U15'),
#  array(['tomorrow', 'thought', 'meant', 'look', 'll'], dtype='<U15'),
#  array(['week', 'wednesday', 'way', 'today', 'fancy', 'club'], dtype='<U15'),
#  array(['happen', 'days'], dtype='<U15'),
#  array(['week', 'trip', 'missed', 'lol', 'finally'], dtype='<U15'),
#  array(['wif', 'family'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['smoke', 'like', 'job', 'great'], dtype='<U15'),
#  array(['time'], dtype='<U15'),
#  array(['thinking', 'said', 'guys', 'getting'], dtype='<U15'),
#  array(['nigeria'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['time', 'prob'], dtype='<U15'),
#  array(['ready'], dtype='<U15'),
#  array(['mum', 'going'], dtype='<U15'),
#  array(['worry', 'worried', 'way', 've', 'sure', 'slow', 'said', 'quite',
#         'll', 'know', 'just', 'guess'], dtype='<U15'),
#  array(['yes', 'way', 'save', 'rent'], dtype='<U15'),
#  array(['touch', 'sweet', 'night', 'mind', 'love', 'life', 'heart', 'good',
#         'frnds', 'dreams', 'amp'], dtype='<U15'),
#  array(['sleeping', 'phone', 'paper', 'details'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['lor'], dtype='<U15'),
#  array(['watching', 'tv', 'nice', 'lor', 'like'], dtype='<U15'),
#  array(['worry', 'vl', 'til', 'party', 'enjoy', 'dont', 'day', 'come',
#         'big'], dtype='<U15'),
#  array(['thing', 'remember', 'problem', 'free', 'did'], dtype='<U15'),
#  array(['yes', 'open', 'need', 'baby'], dtype='<U15'),
#  array(['ring', 'gonna'], dtype='<U15'),
#  array(['yes', 'know', 'don', 'cause', 'care'], dtype='<U15'),
#  array(['texting', 'mean', 'know'], dtype='<U15'),
#  array(['xx', 'wanna', 'set', 'po', 'phone', 'meet', 'luv', 'cum', 'chat',
#         'calls'], dtype='<U15'),
#  array(['use', 'told', 'times', 'listen', 'laugh'], dtype='<U15'),
#  array(['yeah', 'wot', 'remember', 'hmm'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['pls', 'hope', 'great', 'feeling', 'abiola'], dtype='<U15'),
#  array(['year', 'princess', 'new', 'happy'], dtype='<U15'),
#  array(['time', 'just', 'got', 'finished', 'eating'], dtype='<U15'),
#  array(['think', 'shit', 'second', 'save', 'really', 'night'], dtype='<U15'),
#  array(['sorry', 'pls', 'missed', 'hi'], dtype='<U15'),
#  array(['understand', 'th', 'post', 'office', 'man', 'lt', 'house',
#         'holiday', 'gt', 'coz'], dtype='<U15'),
#  array(['thinking', 'forgot', 'come', 'chennai', 'auction'], dtype='<U15'),
#  array(['way', 'new'], dtype='<U15'),
#  array(['week', 'says', 'money', 'll', 'got', 'friend', 'end'],
#        dtype='<U15'),
#  array(['today', 'text', 'sexy', 'reply', 'msg', 'meet', 'just', 'join',
#         'date', 'age'], dtype='<U15'),
#  array(['food'], dtype='<U15'),
#  array(['today', 'thank', 'sorry', 'oh', 'missed', 'love', 'hear',
#         'having', 'good'], dtype='<U15'),
#  array(['wan', 'tickets', 'reach', 'orchard', 'buy'], dtype='<U15'),
#  array(['sms', 'min', 'messages', 'hi'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['lemme', 'know', 'aight'], dtype='<U15'),
#  array(['xx', 'wanna', 'time', 'po', 'nite', 'luv', 'hope', 'cum', 'chat',
#         'calls'], dtype='<U15'),
#  array(['pound', 'lose', 'lol', 'just', 'end', 'day'], dtype='<U15'),
#  array(['making', 'fun', 'cool'], dtype='<U15'),
#  array(['ve', 'try', 'think', 'th', 'sister', 'pick', 'll', 'just',
#         'going', 'evening', 'don'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['wont'], dtype='<U15'),
#  array(['xxx', 'wot', 'town', 'pub', 'nite', 'mo', 'love', 'jus', 'goin',
#         'end', 'didnt', 'da', 'alrite'], dtype='<U15'),
#  array(['work', 'watch', 'tv', 'today', 'meh', 'got'], dtype='<U15'),
#  array(['treat', 'promise', 'good', 'care', 'baby'], dtype='<U15'),
#  array(['times', 'just'], dtype='<U15'),
#  array(['speak', 'shall', 'minutes', 'lt', 'know', 'gt'], dtype='<U15'),
#  array(['want', 'tomorrow', 'text', 'reply', 'phone', 'nokia', 'new',
#         'mobile', 'minutes', 'free', 'colour', 'camcorder'], dtype='<U15'),
#  array(['yes', 've', 'oh', 'little', 'kind', 'just', 'home'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['missing'], dtype='<U15'),
#  array(['lor'], dtype='<U15'),
#  array(['ok'], dtype='<U15'),
#  array(['sex', 'looking'], dtype='<U15'),
#  array(['thanks', 'really', 'looking'], dtype='<U15'),
#  array(['time', 'pm', 'pick', 'park', 'll', 'ill'], dtype='<U15'),
#  array(['nice', 'la', 'just'], dtype='<U15'),
#  array(['took', 'thing', 'speak', 'soon', 'pics', 'mo', 'like', 'hows'],
#        dtype='<U15'),
#  array(['talking'], dtype='<U15'),
#  array(['yeah', 'll', 'leave'], dtype='<U15'),
#  array(['sent', 'princess', 'just', 'bed'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['tea', 'msg', 'coffee', 'chikku'], dtype='<U15'),
#  array(['work', 'warm', 'ok', 'night', 'need', 'll', 'know', 'just',
#         'drink', 'bath'], dtype='<U15'),
#  array(['wat', 'tonight', 'thk', 'eat'], dtype='<U15'),
#  array(['sad', 'need', 'love', 'crave', 'babe'], dtype='<U15'),
#  array(['watching', 'thing', 'house', 'getting', 'especially'],
#        dtype='<U15'),
#  array(['wine'], dtype='<U15'),
#  array(['love'], dtype='<U15'),
#  array(['uk', 'great', 'games', 'free', 'dear'], dtype='<U15'),
#  array(['texts', 'tell', 'stop', 'rate', 'min', 'like', 'just'],
#        dtype='<U15'),
#  array(['watch', 'wat', 'waiting', 'wait', 'tv', 'stuff', 'outside',
#         'home', 'got', 'dat', 'cos', 'car', 'bored'], dtype='<U15'),
#  array(['word', 'txt', 'tc', 'prize', 'phone', 'nokia', 'guaranteed',
#         'collect'], dtype='<U15'),
#  array(['sorry', 'place', 'getting', 'come'], dtype='<U15'),
#  array(['thought', 'slave', 'said', 'late', 'hours', 'hmmm'], dtype='<U15'),
#  array(['year', 'wondering', 've', 'texts', 'sending', 'old', 'number',
#         'heard', 'got', 'friends', 'best'], dtype='<U15'),
#  array(['yar', 'wait', 'stay', 'sch', 'room', 'quite', 'mum', 'morning',
#         'lunch', 'lor', 'home', 'hee', 'finish', 'clean'], dtype='<U15'),
#  array(['till', 'special', 'people', 'life', 'ends', 'da'], dtype='<U15'),
#  array(['wif', 'wan', 'meh', 'leave', 'lar', 'da'], dtype='<U15'),
#  array(['didnt', 'da'], dtype='<U15'),
#  array(['www', 'word', 'won', 'week', 'urgent', 'txt', 'prize', 'pobox',
#         'net', 'free', 'claim'], dtype='<U15'),
#  array(['won', 'service', 'prize', 'pm', 'guaranteed', 'customer', 'cash'],
#        dtype='<U15'),
#  array(['ur', 'suite', 'send', 'row', 'pounds', 'lands', 'hl', 'cash',
#         'balance'], dtype='<U15'),
#  array(['loving', 'love', 'kiss', 'home'], dtype='<U15'),
#  array(['yeah', 'work', 'week', 'stuff', 'started', 'guys', 'fun', 'fine',
#         'easy'], dtype='<U15'),
#  array(['xy', 'wif', 'watch', 'wan', 'sat', 'rite', 'mayb', 'free',
#         'darren'], dtype='<U15'),
#  array(['going', 'bed'], dtype='<U15'),
#  array(['yup', 'thanx'], dtype='<U15'),
#  array(['eat', 'able'], dtype='<U15'),
#  array(['lor', 'juz'], dtype='<U15'),
#  array(['rate', 'po', 'national', 'min', 'live', 'just', 'hot', 'box'],
#        dtype='<U15'),
#  array(['told', 'thank', 'sister', 'sexy', 'remember', 'love', 'hope',
#         'hey', 'grins', 'babe'], dtype='<U15'),
#  array(['pa', 'lt', 'gt', 'brother'], dtype='<U15'),
#  array(['thanks', 'comin', 'aight'], dtype='<U15'),
#  array(['room', 'dear'], dtype='<U15'),
#  array(['welcome', 'credit', 'com', 'bad'], dtype='<U15'),
#  array(['valid', 'urgent', 'prize', 'number', 'mobile', 'line', 'land',
#         'hrs', 'guaranteed', 'claim', 'awarded'], dtype='<U15'),
#  array(['want', 'money', 'aight'], dtype='<U15'),
#  array(['love', 'lot'], dtype='<U15'),
#  array(['sms', 'chat'], dtype='<U15'),
#  array(['www', 'weekend', 'text', 'prize', 'guaranteed', 'com', 'collect'],
#        dtype='<U15'),
#  array(['work', 'place', 'news', 'leave', 'friday', 'coming'], dtype='<U15'),
#  array(['ve', 'told', 'times', 'story', 'like', 'ask'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['watching', 'tv', 'jus', 'finish'], dtype='<U15'),
#  array(['mm', 'food', 'da'], dtype='<U15'),
#  array(['remember', 'day'], dtype='<U15'),
#  array(['text', 'stop', 'opt', 'min', 'line', 'just', 'info', 'com',
#         'check', 'bt'], dtype='<U15'),
#  array(['free'], dtype='<U15'),
#  array(['yesterday', 'urgent', 'prize', 'pm', 'nd', 'contact',
#         'collection', 'claim', 'awaiting', 'attempt'], dtype='<U15'),
#  array(['thanks', 'say'], dtype='<U15'),
#  array(['ur', 'tot', 'ok', 'miss', 'love', 'hope', 'day', 'care'],
#        dtype='<U15'),
#  array(['tel', 'reply', 'read', 'msgs', 'just', 'dont'], dtype='<U15'),
#  array(['bit', 'aight'], dtype='<U15'),
#  array(['th'], dtype='<U15'),
#  array(['win', 'weekly', 'txt', 'rate', 'free', 'entry', 'details', 'comp',
#         'chance', 'apply'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['lemme', 'know'], dtype='<U15'),
#  array(['www', 'welcome', 'weekend', 'uk', 'lots', 'got', 'dear', 'cash',
#         'best', 'away'], dtype='<U15'),
#  array(['wasn', 'ur', 'think', 'sorry', 'nite', 'im', 'bout'], dtype='<U15'),
#  array(['reply', 'pls'], dtype='<U15'),
#  array(['today', 'joined', 'job', 'got'], dtype='<U15'),
#  array(['smiling', 'pain', 'hows', 'dear'], dtype='<U15'),
#  array(['make', 'course'], dtype='<U15'),
#  array(['test', 'nd'], dtype='<U15'),
#  array(['yesterday', 'told', 'oh', 'getting', 'face', 'dream', 'cause'],
#        dtype='<U15'),
#  array(['wkly', 'win', 'txt', 'sp', 'quiz', 'know'], dtype='<U15'),
#  array(['ya', 'sweet', 'needs', 'little'], dtype='<U15'),
#  array(['happened', 'fuck', 'come', 'came', 'babe'], dtype='<U15'),
#  array(['thought', 'send', 'safe', 'numbers', 'missed', 'man', 'let',
#         'know', 'just', 'ill', 'great', 'day'], dtype='<U15'),
#  array(['wat', 'tmr', 'time', 'remember', 'meeting', 'mayb', 'lor', 'leh',
#         'dunno'], dtype='<U15'),
#  array(['wait', 'tonight', 'speak', 'soon', 'night', 'isn', 'hope', 'good',
#         'going', 'bad'], dtype='<U15'),
#  array(['ya', 'day'], dtype='<U15'),
#  array(['miss', 'happened', 'boytoy'], dtype='<U15'),
#  array(['sorry'], dtype='<U15'),
#  array(['thats', 'nice', 'eat', 'bad'], dtype='<U15'),
#  array(['life', 'account'], dtype='<U15'),
#  array(['pick', 'later', 'lar'], dtype='<U15'),
#  array(['want', 'say', 'just', 'hear', 'happen', 'dont'], dtype='<U15'),
#  array(['working', 'stupid', 'haf', 'feel', 'da'], dtype='<U15'),
#  array(['saying', 'pub', 'im', 'happy', 'guess'], dtype='<U15'),
#  array(['time', 'tell', 'sun', 'sat', 'hey', 'free', 'course', 'bugis'],
#        dtype='<U15'),
#  array(['wat', 'ur', 'today', 'smile', 'let', 'gud', 'doing', 'different',
#         'did', 'day', 'ask'], dtype='<U15'),
#  array(['got', 'eat', 'den', 'cafe'], dtype='<U15'),
#  array(['ve', 'sch'], dtype='<U15'),
#  array(['time', 'make', 'calls'], dtype='<U15'),
#  array(['www', 'win', 'weekly', 'vouchers', 'ur', 'txt', 'music', 'gift',
#         'free', 'entry', 'draw', 'congratulations', 'com', 'awarded',
#         'age'], dtype='<U15'),
#  array(['stuff', 'look', 'havent', 'got', 'finish', 'da'], dtype='<U15'),
#  array(['won', 'win', 'prize', 'just', 'easy', 'customer', 'computer',
#         'collect'], dtype='<U15'),
#  array(['work', 'msg', 'lesson', 'going', 'book'], dtype='<U15'),
#  array(['thanx', 'birthday'], dtype='<U15'),
#  array(['video', 've', 'think', 'thanks', 'send', 'charged', 'better'],
#        dtype='<U15'),
#  array(['say', 'noe', 'change'], dtype='<U15'),
#  array(['ok', 'like', 'feel'], dtype='<U15'),
#  array(['sun', 'sat', 'oh', 'muz', 'liao', 'den'], dtype='<U15'),
#  array(['won', 'weekends', 'valid', 'urgent', 'trying', 'shows', 'prize',
#         'hours', 'guaranteed', 'draw', 'contact', 'code', 'claim'],
#        dtype='<U15'),
#  array(['round', 'come'], dtype='<U15'),
#  array(['phone', 'lor', 'lar', 'depends'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['ur', 'later', 'exam', 'best'], dtype='<U15'),
#  array(['soon', 'going', 'dinner'], dtype='<U15'),
#  array(['thought', 'home', 'got', 'asap', 'alright'], dtype='<U15'),
#  array(['sent', 'like'], dtype='<U15'),
#  array(['want', 'tell', 'need', 'love', 'look', 'hey', 'fuck', 'feel',
#         'crave'], dtype='<U15'),
#  array(['yes', 'study', 'baby'], dtype='<U15'),
#  array(['wait', 'time', 'sleep', 'need', 'life', 'family', 'change',
#         'care'], dtype='<U15'),
#  array(['ready', 'face'], dtype='<U15'),
#  array(['today', 'office', 'great'], dtype='<U15'),
#  array(['time'], dtype='<U15'),
#  array(['xx', 'wc', 'uk', 'service', 'min', 'live', 'just', 'hard', 'girl',
#         'choose', 'chat'], dtype='<U15'),
#  array(['service', 'pobox', 'phone', 'landline', 'fancy', 'entered',
#         'dating'], dtype='<U15'),
#  array(['tried', 'thought', 'room', 'point', 'dude', 'actually'],
#        dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['yeah', 'probably', 'earlier'], dtype='<U15'),
#  array(['work', 'went', 'sorry', 'nite', 'im', 'got'], dtype='<U15'),
#  array(['hope'], dtype='<U15'),
#  array(['smth', 'send', 'said', 'like', 'juz', 'haf', 'email', 'dun',
#         'dat', 'account'], dtype='<U15'),
#  array(['nice', 'babe'], dtype='<U15'),
#  array(['lose', 'just', 'eat', 'better'], dtype='<U15'),
#  array(['ur', 'suite', 'send', 'row', 'pounds', 'msg', 'lands', 'hl',
#         'cash', 'balance'], dtype='<U15'),
#  array(['thought', 'okay'], dtype='<U15'),
#  array(['sending', 'send', 'messages', 'message', 'lets', 'im', 'free',
#         'com'], dtype='<U15'),
#  array(['times', 'princess', 'night', 'making', 'lt', 'love', 'gt',
#         'great', 'giving', 'enjoy'], dtype='<U15'),
#  array(['wit', 've', 'thank', 'oh', 'hope', 'good', 'enjoy', 'didnt',
#         'company'], dtype='<U15'),
#  array(['yeah', 'tho', 'll', 'don', 'close'], dtype='<U15'),
#  array(['ve', 'said', 'remove', 'ok', 'need', 'mayb', 'got'], dtype='<U15'),
#  array(['watch', 'wan', 'pm', 'ok'], dtype='<U15'),
#  array(['lol'], dtype='<U15'),
#  array(['word', 'text', 'send', 'phone', 'ok', 'mobile', 'just'],
#        dtype='<U15'),
#  array(['guys', 'close'], dtype='<U15'),
#  array(['went', 'rent', 'pay', 'bank'], dtype='<U15'),
#  array(['wanted', 'tell', 'phone', 'meet', 'hey', 'got', 'carlos',
#         'address'], dtype='<U15'),
#  array(['www', 'start', 'reply', 'people', 'new', 'lots', 'date', 'area'],
#        dtype='<U15'),
#  array(['hey', 'happy', 'birthday'], dtype='<U15'),
#  array(['user', 'stop', 'services', 'send', 'id', 'customer'], dtype='<U15'),
#  array(['night', 'little', 'gonna', 'early', 'able'], dtype='<U15'),
#  array(['lor', 'dun'], dtype='<U15'),
#  array(['ll'], dtype='<U15'),
#  array(['urgent', 'tenerife', 'sae', 'ppm', 'po', 'offer', 'landline',
#         'holiday', 'cs', 'collection', 'cash', 'box', 'await'],
#        dtype='<U15'),
#  array(['told', 'join', 'going'], dtype='<U15'),
#  array(['tomorrow', 'place', 'order', 'late', 'christmas'], dtype='<U15'),
#  array(['sir', 'need', 'details', 'date', 'company', 'bank'], dtype='<U15'),
#  array(['wat', 'wan', 'tell', 'looking', 'daddy'], dtype='<U15'),
#  array(['wan', 'oso', 'oh', 'lor', 'ends', 'dun', 'den'], dtype='<U15'),
#  array(['month', 'end'], dtype='<U15'),
#  array(['sister', 'saying', 'month', 'just', 'hope', 'hey', 'having',
#         'great', 'abiola'], dtype='<U15'),
#  array(['went', 'people', 'life', 'home', 'cool', 'college'], dtype='<U15'),
#  array(['wil', 'true', 'start', 'missing', 'makes', 'care'], dtype='<U15'),
#  array(['gud'], dtype='<U15'),
#  array(['say', 'oso', 'oredi', 'like', 'lar', 'dun', 'dat', 'buy'],
#        dtype='<U15'),
#  array(['want', 'hear', 'dont'], dtype='<U15'),
#  array(['wat', 'wan', 'time', 'haf', 'come'], dtype='<U15'),
#  array(['ur', 'thk', 'sad', 'dun', 'abt'], dtype='<U15'),
#  array(['time', 'pick', 'ish', 'going', 'bout'], dtype='<U15'),
#  array(['ur', 'send', 'pounds', 'po', 'msg', 'cash', 'box', 'balance'],
#        dtype='<U15'),
#  array(['babe', 'alright'], dtype='<U15'),
#  array(['private', 'kiss', 'good', 'forget', 'don', 'boy'], dtype='<U15'),
#  array(['sale', 'lol', 'don', 'big'], dtype='<U15'),
#  array(['details'], dtype='<U15'),
#  array(['send', 'da'], dtype='<U15'),
#  array(['talk', 'really', 'need', 'just'], dtype='<U15'),
#  array(['ll', 'just'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['thanx', 'lot'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['thanx', 'ok', 'lor'], dtype='<U15'),
#  array(['think', 'send', 'love', 'good'], dtype='<U15'),
#  array(['statement', 'shows', 'redeemed', 'private', 'points',
#         'identifier', 'expires', 'code', 'account'], dtype='<U15'),
#  array(['words', 'wait', 'morning', 'miss', 'loved', 'love', 'hope',
#         'happy', 'goes', 'day'], dtype='<U15'),
#  array(['street', 'run'], dtype='<U15'),
#  array(['yes', 'reply', 'like', 'know', 'just', 'hi', 'free'], dtype='<U15'),
#  array(['soon', 'reaching', 'orchard', 'going'], dtype='<U15'),
#  array(['tonight', 'soon', 'later', 'gonna', 'awesome'], dtype='<U15'),
#  array(['txt', 'price', 'phones', 'optout', 'month', 'mins', 'free',
#         'camera'], dtype='<U15'),
#  array(['hurry', 'home'], dtype='<U15'),
#  array(['need', 'lunch', 'eat', 'buy'], dtype='<U15'),
#  array(['ready'], dtype='<U15'),
#  array(['yes', 'www', 'stop', 'sms', 'send', 'reply', 'frnd', 'friend',
#         'ac'], dtype='<U15'),
#  array(['worry', 'sure', 'll'], dtype='<U15'),
#  array(['try', 'luv', 'just', 'im', 'il', 'hit', 'fucking', 'cum'],
#        dtype='<U15'),
#  array(['talk'], dtype='<U15'),
#  array(['send', 'going'], dtype='<U15'),
#  array(['work', 'sat', 'liao', 'leh', 'free', 'day', 'booked'],
#        dtype='<U15'),
#  array(['like', 'dat', 'ard'], dtype='<U15'),
#  array(['sale', 'doing', 'cos', 'buy'], dtype='<U15'),
#  array(['took', 'second', 'ok', 'lt', 'gt'], dtype='<U15'),
#  array(['text', 'll', 'cash'], dtype='<U15'),
#  array(['good', 'da'], dtype='<U15'),
#  array(['talk', 'problem', 'later'], dtype='<U15'),
#  array(['pub', 'hi', 'great', 'come'], dtype='<U15'),
#  array(['wat', 'did', 'brother'], dtype='<U15'),
#  array(['waiting', 'trust', 'love', 'light', 'friend', 'best'],
#        dtype='<U15'),
#  array(['snow'], dtype='<U15'),
#  array(['text', 'll', 'let', 'know', 'carlos'], dtype='<U15'),
#  array(['ya', 'going'], dtype='<U15'),
#  array(['umma', 'ok', 'care'], dtype='<U15'),
#  array(['thk', 'say', 'nite', 'nice', 'lor', 'leh', 'lar', 'jus', 'happen',
#         'course', 'bit'], dtype='<U15'),
#  array(['www', 'user', 'urawinner', 'ur', 'today', 'orange', 'lucky',
#         'log', 'information', 'important', 'http', 'fantastic', 'day',
#         'com'], dtype='<U15'),
#  array(['texts', 'stop', 'sale', 'rate', 'national', 'min', 'hot', 'chat'],
#        dtype='<U15'),
#  array(['selected', 'receive', 'ppm', 'pound', 'cs', 'cost', 'close',
#         'award', 'apply'], dtype='<U15'),
#  array(['service', 'pobox', 'dating', 'contact', 'asked'], dtype='<U15'),
#  array(['wen', 'said', 'ok', 'girl', 'comes', 'bout', 'ask'], dtype='<U15'),
#  array(['seeing'], dtype='<U15'),
#  array(['yup', 'noe', 'leh'], dtype='<U15'),
#  array(['lor', 'coming'], dtype='<U15'),
#  array(['prob', 'ok', 'oh'], dtype='<U15'),
#  array(['send', 'noe'], dtype='<U15'),
#  array(['cost'], dtype='<U15'),
#  array(['office', 'min', 'lt', 'gt'], dtype='<U15'),
#  array(['ve', 'online', 'hey', 'finished'], dtype='<U15'),
#  array(['week', 'unsubscribe', 'thanks', 'services', 'ringtone', 'order',
#         'gbp', 'customer', 'charged', 'calling', 'anytime'], dtype='<U15'),
#  array(['tonight', 'pick', 'open', 'aight'], dtype='<U15'),
#  array(['set', 'plans', 'family'], dtype='<U15'),
#  array(['song', 'ok', 'chikku'], dtype='<U15'),
#  array(['meet'], dtype='<U15'),
#  array(['ya', 'ur', 'rite', 'quite', 'fine'], dtype='<U15'),
#  array(['going'], dtype='<U15'),
#  array(['early', 'didn'], dtype='<U15'),
#  array(['send', 'run', 'promise', 'princess', 'pics', 'good', 'chance',
#         'care'], dtype='<U15'),
#  array(['things', 'question', 'just'], dtype='<U15'),
#  array(['hello'], dtype='<U15'),
#  array(['person', 'good'], dtype='<U15'),
#  array(['facebook', 'did'], dtype='<U15'),
#  array(['week', 'just', 'hope', 'having', 'good'], dtype='<U15'),
#  array(['good', 'girls'], dtype='<U15'),
#  array(['ll', 'home', 'doing', 'amp'], dtype='<U15'),
#  array(['right', 'later'], dtype='<U15'),
#  array(['waiting', 'text', 'ringtone', 'free'], dtype='<U15'),
#  array(['words', 'word', 'wit', 'use', 'ur', 'told', 'time', 'things',
#         'tell', 'plz', 'ok', 'nxt', 'far', 'dont', 'didn', 'chikku', 'abt'],
#        dtype='<U15'),
#  array(['www', 'word', 'visit', 'text', 'terms', 'messages', 'message',
#         'free', 'com'], dtype='<U15'),
#  array(['ve', 'tea', 'sure', 'got'], dtype='<U15'),
#  array(['number', 'hi'], dtype='<U15'),
#  array(['watching', 'tv', 'nope', 'home', 'going', 'bored'], dtype='<U15'),
#  array(['office', 'da'], dtype='<U15'),
#  array(['new', 'message'], dtype='<U15'),
#  array(['chennai'], dtype='<U15'),
#  array(['treat', 'mail', 'home', 'days', 'congrats', 'check'], dtype='<U15'),
#  array(['hit'], dtype='<U15'),
#  array(['takes', 'money', 'away'], dtype='<U15'),
#  array(['say', 'know', 'good'], dtype='<U15'),
#  array(['tonight', 'coming'], dtype='<U15'),
#  array(['love', 'bus'], dtype='<U15'),
#  array(['won', 'win', 'send', 'pobox', 'plus', 'nokia', 'free', 'camera',
#         'auction'], dtype='<U15'),
#  array(['thanks', 'love', 'doing'], dtype='<U15'),
#  array(['read', 'light', 'heart', 'goodmorning', 'beautiful'], dtype='<U15'),
#  array(['til', 'probably', 'left', 'haven', 'gonna', 'dinner'],
#        dtype='<U15'),
#  array(['want', 'oh'], dtype='<U15'),
#  array(['yeah', 'ready'], dtype='<U15'),
#  array(['loving'], dtype='<U15'),
#  array(['yrs', 'work', 'week', 'st', 'new', 'got', 'eve', 'comin',
#         'college', 'bath', 'bak'], dtype='<U15'),
#  array(['phone', 'pay', 'offer', 'mobile', 'free', 'ends', 'customer',
#         'claim', 'card', 'camera', 'apply'], dtype='<U15'),
#  array(['possible'], dtype='<U15'),
#  array(['ur', 'sms', 'reply', 'question', 'know', 'end', 'day', 'ac'],
#        dtype='<U15'),
#  array(['pa', 'ill', 'going', 'come', 'college'], dtype='<U15'),
#  array(['win', 'wap', 'uk', 'terms', 'press', 'games', 'game', 'charge',
#         'chance', 'buy'], dtype='<U15'),
#  array(['won', 'urgent', 'reach', 'prize', 'ppm', 'nd', 'mobile', 'caller',
#         'box', 'bonus', 'attempt', 'asap'], dtype='<U15'),
#  array(['true', 'ringtone', 'msg', 'id', 'http', 'free', 'com'],
#        dtype='<U15'),
#  array(['stuff', 'sch', 'got', 'doing', 'come'], dtype='<U15'),
#  array(['wrong', 'phone', 'people', 'don', 'answer'], dtype='<U15'),
#  array(['good', 'evening'], dtype='<U15'),
#  array(['wan', 'mum', 'little', 'lei', 'juz', 'hungry', 'good', 'food',
#         'dun', 'buy', 'bit'], dtype='<U15'),
#  array(['watch', 'wanna', 'movie'], dtype='<U15'),
#  array(['da', 'buy'], dtype='<U15'),
#  array(['xxx', 'want', 'txt', 'time', 'thing', 'sexy', 'msgs', 'im',
#         'hard', 'fancy', 'dont', 'baby', 'babe'], dtype='<U15'),
#  array(['sent', 'pay', 'message', 'lt', 'gt'], dtype='<U15'),
#  array(['yo', 'tonight', 'pick', 'later', 'friend'], dtype='<U15'),
#  array(['saying'], dtype='<U15'),
#  array(['way', 'text', 'll', 'cool'], dtype='<U15'),
#  array(['time', 'text'], dtype='<U15'),
#  array(['sitting', 'life', 'haven', 'eat', 'day'], dtype='<U15'),
#  array(['www', 'weekly', 'want', 'ur', 'uk', 'tones', 'tone', 'text',
#         'reply', 'operator', 'new', 'network', 'gbp', 'best', 'apply'],
#        dtype='<U15'),
#  array(['sorry', 'number', 'don'], dtype='<U15'),
#  array(['wont', 'speak', 'pls', 'friendship', 'ask'], dtype='<U15'),
#  array(['tried', 'reply', 'offer', 'nokia', 'new', 'hit', 'delivery',
#         'contact', 'camcorder'], dtype='<U15'),
#  array(['yup', 'trying', 'studying', 'sorry', 'sent', 'msg'], dtype='<U15'),
#  array(['yeah', 'ya', 'neva', 'cheers', 'came'], dtype='<U15'),
#  array(['tomorrow', 'help', 'going'], dtype='<U15'),
#  array(['ok'], dtype='<U15'),
#  array(['thk', 'tell', 'oops', 'haf', 'dun', 'check'], dtype='<U15'),
#  array(['ur', 'thinking', 'save', 'red'], dtype='<U15'),
#  array(['available'], dtype='<U15'),
#  array(['time', 'soon', 'little', 'getting', 'cool'], dtype='<U15'),
#  array(['won', 'weekends', 'valid', 'urgent', 'trying', 'shows', 'prize',
#         'pm', 'hrs', 'guaranteed', 'draw', 'contact', 'code', 'claim'],
#        dtype='<U15'),
#  array(['want'], dtype='<U15'),
#  array(['wish', 'right'], dtype='<U15'),
#  array(['come'], dtype='<U15'),
#  array(['came'], dtype='<U15'),
# ...
#  array(['world', 'run', 'maybe', 'life', 'lets', 'let', 'feeling'],
#        dtype='<U15'),
#  array(['weekly', 'week', 'stop', 'st', 'sms', 'send', 'ringtone', 'free'],
#        dtype='<U15'),
#  array(['nt', 'nights', 'liao', 'ex'], dtype='<U15'),
#  array(['ur', 'time', 'ok', 'enjoy', 'dinner'], dtype='<U15'),
#  array(['swing', 'probably', 'gonna', 'bit'], dtype='<U15'),
#  array(['need'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['valid', 'text', 'messages', 'free'], dtype='<U15'),
#  array(['wait', 'sun', 'pls', 'place', 'invited', 'hot', 'going', 'family',
#         'actually'], dtype='<U15'),
#  array(['win', 'luck', 'big'], dtype='<U15'),
#  array(['lol', 'hmm'], dtype='<U15'),
#  array(['sis', 'sch', 'quite', 'paper', 'nope', 'lor', 'll', 'got',
#         'going', 'fri', 'early', 'da', 'cos'], dtype='<U15'),
#  array(['use', 'think', 'ni', 'got', 'good', 'don'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['sure', 'noon', 'night', 'know'], dtype='<U15'),
#  array(['yes', 'remember', 'naughty', 'make', 'eh', 'did'], dtype='<U15'),
#  array(['saw', 'old'], dtype='<U15'),
#  array(['wx', 'urgent', 'tenerife', 'sae', 'ppm', 'landline', 'holiday',
#         'cs', 'complimentary', 'collection', 'cash', 'box', 'await'],
#        dtype='<U15'),
#  array(['lol', 'laugh', 'hoping'], dtype='<U15'),
#  array(['waiting', 'spend', 'goodnight', 'forget', 'days'], dtype='<U15'),
#  array(['soon', 'care'], dtype='<U15'),
#  array(['right', 'days'], dtype='<U15'),
#  array(['trying', 'phone', 'fucking', 'answer'], dtype='<U15'),
#  array(['xy', 'watching', 'wants', 'shopping', 'shop', 'movie'],
#        dtype='<U15'),
#  array(['way', 'search', 'live', 'life', 'happiness', 'comes'],
#        dtype='<U15'),
#  array(['www', 'wq', 'uk', 'tones', 'tone', 'rply', 'pobox', 'nokia',
#         'getzed'], dtype='<U15'),
#  array(['wonder', 'wish', 'things', 'pls', 'love', 'laugh', 'different',
#         'able'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['time', 'long', 'finished', 'er', 'ago'], dtype='<U15'),
#  array(['start', 'leave'], dtype='<U15'),
#  array(['wait', 'say', 'meant', 'getting', 'bored'], dtype='<U15'),
#  array(['tell', 'start', 'shall', 'reach', 'pls', 'holiday', 'dear', 'day',
#         'coming', 'case'], dtype='<U15'),
#  array(['sounds', 'okay', 'meant', 'just', 'better'], dtype='<U15'),
#  array(['tonight', 'special', 'lt', 'know', 'gt', 'doin'], dtype='<U15'),
#  array(['voice', 'speak', 'problem', 'mobile', 'listen', 'later', 'calls'],
#        dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['taking', 'min', 'lt', 'like', 'gt'], dtype='<U15'),
#  array(['street', 'lady'], dtype='<U15'),
#  array(['waiting', 'free'], dtype='<U15'),
#  array(['earlier'], dtype='<U15'),
#  array(['wanna', 'da'], dtype='<U15'),
#  array(['yo', 'sorry'], dtype='<U15'),
#  array(['good', 'evening'], dtype='<U15'),
#  array(['ugh'], dtype='<U15'),
#  array(['make', 'lt', 'gt', 'dad'], dtype='<U15'),
#  array(['ya', 'wana', 'thk', 'haha'], dtype='<U15'),
#  array(['tomorrow', 'time', 'party', 'night', 'ish', 'im', 'home', 'hi',
#         'having', 'good', 'day'], dtype='<U15'),
#  array(['wake', 'slept', 'late', 'knew'], dtype='<U15'),
#  array(['txt', 'today', 'sms', 'nokia', 'new', 'join', 'free', 'auction'],
#        dtype='<U15'),
#  array(['really', 'brother', 'big'], dtype='<U15'),
#  array(['work', 'right', 'need', 'home', 'coming', 'class'], dtype='<U15'),
#  array(['ringtone', 'reply', 'real', 'free'], dtype='<U15'),
#  array(['watching', 'wat', 'movie', 'abt'], dtype='<U15'),
#  array(['watch', 'thk', 'saw', 'quite', 'ok', 'need', 'nd', 'lor', 'leh',
#         'ard'], dtype='<U15'),
#  array(['ur', 'night', 'life', 'good', 'enjoy'], dtype='<U15'),
#  array(['ready', 'finally'], dtype='<U15'),
#  array(['walk', 'took', 'tomorrow', 'home'], dtype='<U15'),
#  array(['say', 'like', 'hi', 'dont'], dtype='<U15'),
#  array(['thats', 'going'], dtype='<U15'),
#  array(['address'], dtype='<U15'),
#  array(['won', 'prize', 'claim', 'cash'], dtype='<U15'),
#  array(['wanna', 've', 'time', 'tho', 'shopping', 'ready', 'night',
#         'naughty', 'meet', 'little', 'kind', 'bought'], dtype='<U15'),
#  array(['week', 'tones', 'tone', 'terms', 'stop', 'gbp', 'enjoy', 'cost',
#         'com', 'club'], dtype='<U15'),
#  array(['think', 'sexy', 'need', 'morning', 'good', 'crave', 'boytoy'],
#        dtype='<U15'),
#  array(['year', 'ts', 'nights', 'cs', 'book', 'apply'], dtype='<U15'),
#  array(['real'], dtype='<U15'),
#  array(['second', 'lt', 'like', 'half', 'gt', 'gets'], dtype='<U15'),
#  array(['ya', 'love', 'hows', 'hope', 'good', 'boy'], dtype='<U15'),
#  array(['send', 'lar', 'eh'], dtype='<U15'),
#  array(['sure', 'available'], dtype='<U15'),
#  array(['good'], dtype='<U15'),
#  array(['plan', 'just'], dtype='<U15'),
#  array(['work', 'things', 'possible', 'makes', 'love', 'hope', 'christmas',
#         'beautiful'], dtype='<U15'),
#  array(['soon', 'little', 'leaving'], dtype='<U15'),
#  array(['word', 'txt', 'selected', 'receive', 'ok', 'msg', 'door', 'claim',
#         'bonus'], dtype='<U15'),
#  array(['today', 'thanks', 'hope', 'good', 'day'], dtype='<U15'),
#  array(['way', 'tonight', 'sleep', 'number', 'new', 'mate'], dtype='<U15'),
#  array(['tmr', 'pm', 'orchard', 'mrt', 'meet', 'hey', 'dead'], dtype='<U15'),
#  array(['sounds', 'good'], dtype='<U15'),
#  array(['txts', 'stop', 'send', 'reply', 'msg', 'men', 'love', 'home',
#         'hey', 'help', 'freemsg', 'feeling'], dtype='<U15'),
#  array(['ok', 'hope', 'gettin', 'care', 'babe'], dtype='<U15'),
#  array(['ur', 'morning', 'life', 'happiness', 'good', 'days', 'day', 'bad'],
#        dtype='<U15'),
#  array(['wat', 'thk', 'quite', 'makes', 'lucky', 'll', 'home', 'dad',
#         'come', 'ask', 'actually'], dtype='<U15'),
#  array(['waiting', 'send', 'real', 'people', 'msg', 'free', 'chat', 'area'],
#        dtype='<U15'),
#  array(['old', 'live', 'cause'], dtype='<U15'),
#  array(['mins', 'look', 'ill'], dtype='<U15'),
#  array(['wanna', 'study', 'don'], dtype='<U15'),
#  array(['park', 'juz', 'huh', 'got', 'den', 'best', 'ah'], dtype='<U15'),
#  array(['tomorrow', 'point', 'figure', 'doing', 'come', 'busy'],
#        dtype='<U15'),
#  array(['miss', 'fine'], dtype='<U15'),
#  array(['today', 'going'], dtype='<U15'),
#  array(['ya', 'mr', 'morning', 'hows', 'good'], dtype='<U15'),
#  array(['send', 'plus', 'dont'], dtype='<U15'),
#  array(['time', 'lt', 'gt', 'come'], dtype='<U15'),
#  array(['new', 'address'], dtype='<U15'),
#  array(['sorry', 'sir', 'meeting', 'll', 'later'], dtype='<U15'),
#  array(['red', 'believe'], dtype='<U15'),
#  array(['want', 'walk', 'things', 'tell', 'say', 'problem', 'listen',
#         'know', 'going', 'don', 'doing'], dtype='<U15'),
#  array(['wil', 'tomorrow', 'late', 'gym', 'goodnight', 'come'],
#        dtype='<U15'),
#  array(['watch', 'thought', 'thing', 'thats', 'th', 'kind', 'just', 'cos'],
#        dtype='<U15'),
#  array(['smiling', 'seeing', 'message', 'just', 'gud', 'friendship'],
#        dtype='<U15'),
#  array(['oredi', 'comin'], dtype='<U15'),
#  array(['means', 'huh', 'havent', 'finished', 'fast', 'dat'], dtype='<U15'),
#  array(['try', 'kind', 'come'], dtype='<U15'),
#  array(['yup'], dtype='<U15'),
#  array(['yijue', 'haf', 'com'], dtype='<U15'),
#  array(['xx', 'txt', 'text', 'stop', 'real', 'phone', 'msg', 'match',
#         'looking', 'cost'], dtype='<U15'),
#  array(['use', 'type', 'plz', 'nokia', 'motorola', 'mobile', 'make', 'lt',
#         'gt', 'coz', 'card', 'calling', 'attempt', 'amp'], dtype='<U15'),
#  array(['st', 'pub', 'ok', 'gas'], dtype='<U15'),
#  array(['xy', 'wan', 'thk', 'rain', 'ok', 'leh', 'got', 'going', 'gd',
#         'fast', 'dun'], dtype='<U15'),
#  array(['minute', 'haha', 'awesome'], dtype='<U15'),
#  array(['ur', 'txt', 'news', 'new', 'mobile', 'free', 'club'], dtype='<U15'),
#  array(['times', 'oh', 'lt', 'like', 'gt', 'don'], dtype='<U15'),
#  array(['person', 'll', 'just'], dtype='<U15'),
#  array(['word', 'wanna', 'try', 'send', 'rcvd', 'po', 'msg', 'mobile',
#         'laugh', 'chat', 'box'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['wot', 'think', 'sleep', 'mind', 'just', 'friend', 'dont', 'don'],
#        dtype='<U15'),
#  array(['yup', 'soon', 'right', 'leaving'], dtype='<U15'),
#  array(['christmas'], dtype='<U15'),
#  array(['new', 'mobile', 'just', 'great', 'comes', 'buy'], dtype='<U15'),
#  array(['say', 'neva', 'lei', 'dunno'], dtype='<U15'),
#  array(['things', 'smiling', 'enjoy', 'day', 'beautiful'], dtype='<U15'),
#  array(['just', 'don'], dtype='<U15'),
#  array(['www', 'weeks', 'voucher', 'uk', 'txt', 'ts', 'texts', 'stop',
#         'pc', 'offer', 'http', 'dear', 'cs', 'claim', 'apply'],
#        dtype='<U15'),
#  array(['wanna', 'send', 'right', 'pic', 'lol', 'hair', 'actually'],
#        dtype='<U15'),
#  array(['wat', 'time', 'thinking', 'haha', 'going'], dtype='<U15'),
#  array(['yesterday', 'sitting', 'lol', 'just', 'got', 'did'], dtype='<U15'),
#  array(['weekend', 'week', 'town'], dtype='<U15'),
#  array(['today', 'mu', 'going'], dtype='<U15'),
#  array(['hi', 'doing', 'baby'], dtype='<U15'),
#  array(['want', 'right', 'really', 'ready', 'need', 'maybe', 'going'],
#        dtype='<U15'),
#  array(['want', 'texts', 'reply', 'phone', 'nokia', 'new', 'mobile',
#         'minutes', 'free', 'colour', 'camcorder'], dtype='<U15'),
#  array(['number', 'msg', 'mobile', 'mistake', 'landline', 'free', 'bt'],
#        dtype='<U15'),
#  array(['send', 'id', 'da'], dtype='<U15'),
#  array(['rs', 'lt', 'hello', 'gt'], dtype='<U15'),
#  array(['week', 'want', 'tired', 'll'], dtype='<U15'),
#  array(['love'], dtype='<U15'),
#  array(['thats', 'search', 'love', 'let', 'know', 'just', 'hold', 'dont',
#         'called'], dtype='<U15'),
#  array(['says', 'place', 'pick', 'like', 'hour', 'cool'], dtype='<U15'),
#  array(['town', 'think', 'sorry', 'long', 'family', 'don', 'away'],
#        dtype='<U15'),
#  array(['dude'], dtype='<U15'),
#  array(['pls', 'open'], dtype='<U15'),
#  array(['yup', 'orchard', 'lose', 'haha'], dtype='<U15'),
#  array(['set', 'press', 'friends'], dtype='<U15'),
#  array(['voucher', 'till', 'shop', 'ppm', 'po', 'mobile', 'drop', 'cost',
#         'cash', 'bt', 'box'], dtype='<U15'),
#  array(['sir', 'free'], dtype='<U15'),
#  array(['think', 'remember', 'morning', 'mom', 'missing', 'love', 'kiss',
#         'home'], dtype='<U15'),
#  array(['yup', 'wan', 'ok', 'lor', 'dun'], dtype='<U15'),
#  array(['st', 'sch', 'neva', 'mind', 'lor', 'eat'], dtype='<U15'),
#  array(['won', 'use', 'money', 'lol', 'feel', 'dinner', 'bad'],
#        dtype='<U15'),
#  array(['wanna', 'text', 'stop', 'im', 'home', 'hi', 'com', 'chat', 'babe'],
#        dtype='<U15'),
#  array(['like', 'job'], dtype='<U15'),
#  array(['want', 'sounds', 'good', 'come', 'aight'], dtype='<U15'),
#  array(['night', 'hmm'], dtype='<U15'),
#  array(['work', 'tmr', 'sad', 'neva', 'lunch', 'lot', 'lor', 'lei', 'hee',
#         'hear', 'got', 'fr', 'buy', 'aft'], dtype='<U15'),
#  array(['ur', 'send', 'rply', 'really', 'msg', 'game', 'friends', 'dis',
#         'colour', 'best'], dtype='<U15'),
#  array(['wq', 'txt', 'try', 'pobox', 'new', 'msg', 'like', 'em', 'don',
#         'dating', 'chat', 'bored'], dtype='<U15'),
#  array(['today', 'sent', 'problem', 'ok', 'message', 'just', 'fun'],
#        dtype='<U15'),
#  array(['hey', 'gym'], dtype='<U15'),
#  array(['www', 'suite', 'prize', 'min', 'hl', 'don', 'customer', 'busy'],
#        dtype='<U15'),
#  array(['wont', 'wife', 'use', 'doctor', 'better'], dtype='<U15'),
#  array(['things', 'pub', 'later', 'got'], dtype='<U15'),
#  array(['went', 'sorry', 'early', 'bed'], dtype='<U15'),
#  array(['tell', 'pete', 'past', 'im', 'hav', 'cos', 'bit'], dtype='<U15'),
#  array(['xxx', 'wanna', 'tomorrow', 'time', 'sure', 'spend', 'ok', 'love',
#         'im', 'finish', 'evening', 'cos'], dtype='<U15'),
#  array(['plan'], dtype='<U15'),
#  array(['type', 'sent', 'like', 'just', 'food'], dtype='<U15'),
#  array(['yup', 'leave', 'hey', 'fri', 'day', 'ask'], dtype='<U15'),
#  array(['thank', 'princess', 'pretty', 'pics', 'hi'], dtype='<U15'),
#  array(['sunday', 'lt', 'house'], dtype='<U15'),
#  array(['yes', 'wish', 'want', 'princess', 'night'], dtype='<U15'),
#  array(['tell', 'shall', 'need', 'like', 'let', 'know', 'good'],
#        dtype='<U15'),
#  array(['phone', 'messages'], dtype='<U15'),
#  array(['said', 'choose', 'called'], dtype='<U15'),
#  array([], dtype='<U15'),
#  array(['tonight', 'probably', 'lt', 'later', 'gonna'], dtype='<U15'),
#  array(['good'], dtype='<U15'),
#  array(['way', 'going'], dtype='<U15'),
#  array(['hear', 'happened'], dtype='<U15'),
#  array(['office', 'msg', 'break'], dtype='<U15'),
#  array(['fine'], dtype='<U15'),
#  array(['doctor', 'day', 'care'], dtype='<U15'),
#  array(['problem', 'ok', 'frm'], dtype='<U15'),
#  array(['thing', 'sorry', 'really', 'im', 'getting', 'feel', 'bad'],
#        dtype='<U15'),
#  array(['wanted', 'talk', 'start', 'late', 'got', 'dad'], dtype='<U15'),
#  array(['nice'], dtype='<U15'),
#  array(['way', 'want', 'tonight', 'oh', 'food'], dtype='<U15'),
#  array(['stuff', 'new', 'hear', 'did', 'comes'], dtype='<U15'),
#  array(['says', 'leave', 'gonna'], dtype='<U15'),
#  array(['wif', 'wan', 'ur', 'tickets', 'thk', 'quite', 'ok', 'lor', 'look',
#         'like', 'late', 'frens', 'darren', 'cos'], dtype='<U15'),
#  array(['wif', 'tmr', 'set', 'neva', 'mayb', 'later', 'lar', 'help', 'got',
#         'da', 'come'], dtype='<U15'),
#  array(['today', 'old', 'men', 'know', 'hope', 'great', 'friends', 'cos'],
#        dtype='<U15'),
#  array(['thanks', 'great', 'day'], dtype='<U15'),
#  array(['week', 'wap', 'time', 'stop', 'reply', 'pics', 'orange', 'hit',
#         'free'], dtype='<U15'),
#  array(['wat', 'wan', 'today', 'time'], dtype='<U15'),
#  array(['yup', 'thk', 'need', 'mah', 'cos', 'better'], dtype='<U15'),
#  array(['job', 'getting'], dtype='<U15'),
#  array(['think', 'things', 'saying', 'say', 'like', 'hard', 'believe'],
#        dtype='<U15'),
#  array(['come'], dtype='<U15'),
#  array(['week', 'ur', 'txt', 'tone', 'tell', 'st', 'reply', 'mob', 'just',
#         'info', 'hl', 'friends', 'free'], dtype='<U15'),
#  array(['wonder', 'thk', 'seeing', 'saw', 'dun', 'cos', 'car'],
#        dtype='<U15'),
#  array(['having', 'haha', 'dinner'], dtype='<U15'),
#  array(['true', 'really', 'jus', 'hope', 'haven', 'feel', 'cos'],
#        dtype='<U15'),
#  array(['good', 'going'], dtype='<U15'),
#  array(['want', 'video', 'tomorrow', 'reply', 'rental', 'price', 'network',
#         'mins', 'line', 'latest', 'half', 'delivery', 'anytime'],
#        dtype='<U15'),
#  array(['meet', 'late', 'hey', 'ah'], dtype='<U15'),
#  array(['thinking', 'lor', 'hmm'], dtype='<U15'),
#  array(['tot', 'say', 'lei'], dtype='<U15'),
#  array(['ur', 'thinks', 'special', 'secret', 'make', 'looking', 'contact'],
#        dtype='<U15'),
#  array(['video', 'txts', 'rental', 'price', 'phones', 'optout', 'mths',
#         'mobileupd', 'mins', 'line', 'half', 'free', 'camera'],
#        dtype='<U15'),
#  array(['tone', 'thanks', 'services', 'ringtone', 'order', 'number',
#         'mobile', 'customer', 'charged'], dtype='<U15'),
#  array(['wan', 'tonight', 'dinner', 'come'], dtype='<U15'),
#  array(['nah'], dtype='<U15'),
#  array(['sleep', 'going'], dtype='<U15'),
#  array(['took', 'mr'], dtype='<U15'),
#  array(['ur', 'today', 'think', 'things', 'thanks', 'sister', 'reply',
#         'really', 'need', 'money', 'make', 'later', 'easy', 'coming'],
#        dtype='<U15'),
#  array(['send', 'reply', 'mobile', 'message', 'll', 'just'], dtype='<U15'),
#  array(['did', 'dad'], dtype='<U15'),
#  array(['ve', 'txt', 'invited', 'final', 'dear', 'contact', 'chat',
#         'attempt'], dtype='<U15'),
#  array(['work'], dtype='<U15'),
#  array(['won', 'valid', 'urgent', 'trying', 'todays', 'shows', 'prize',
#         'line', 'land', 'hrs', 'guaranteed', 'draw', 'contact', 'claim'],
#        dtype='<U15'),
#  array(['hospital', 'home', 'evening', 'da'], dtype='<U15'),
#  array(['wont', 'thanks', 'place', 'oh', 'lol', 'babe'], dtype='<U15'),
#  array(['ur', 'pick'], dtype='<U15'),
#  array(['service', 'phone', 'new', 'music', 'mobile', 'live', 'just',
#         'free', 'content'], dtype='<U15'),
#  array(['happen', 'dear'], dtype='<U15'),
#  array(['www', 'uk', 'txt', 'text', 'questions', 'info', 'games', 'com'],
#        dtype='<U15'),
#  array(['getting'], dtype='<U15'),
#  array(['ring', 'guys', 'gift', 'comes'], dtype='<U15'),
#  ...]

# %% [markdown]
# ### ml model fit(train) => predict(test) => accuracy check

# %%
#정확도 분석을 해보자.
SA_lr = LogisticRegression(random_state= 0)

# %%
#train문제(x)와 정답(y)을 fit시켜보자.
SA_lr.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
#test문제의 예측값을 변수에 넣어보자.
test_predict = SA_lr.predict(X_test)

# %%
#test정답에 대한 문제예측의 정확도를 print해보자.
print('스팸 메일 분석 정확도', round(accuracy_score(y_test, test_predict), 5))
# Out:
# 스팸 메일 분석 정확도 0.96277

# %% [markdown]
# ### 하나의 메일에 대해 스팸인지 아닌지 판별해보자.
# ### one mail => predict!!

# %%
#v2컬럼의 15번째 행을 변수에 넣어 보자.
sp = spam_df['v2'][15]
sp
# Out:
# 'XXXMobileMovieClub To use your credit click the WAP link in the next txt message or click here http wap xxxmobilemovieclub com n QJKGIGHJJGCBL'

# %%
#정규식을 사용하여 영어외 문자 제거.
sp2 = re.sub(r'[^[a-zA-Z]*$', "", sp)
sp2
# Out:
# 'XXXMobileMovieClub To use your credit click the WAP link in the next txt message or click here http wap xxxmobilemovieclub com n QJKGIGHJJGCBL'

# %%
#transform시키자.
sp_tfidf = tfidf.transform([sp2])
sp_tfidf
# Out:
# <1x928 sparse matrix of type '<class 'numpy.float64'>'
# 	with 9 stored elements in Compressed Sparse Row format>

# %%
#스팸인지 아닌지 예측
sp2_predict = SA_lr.predict(sp_tfidf)
sp2_predict, sp2_predict[0]
# Out:
# (array(['spam'], dtype=object), 'spam')

# %%
if(sp2_predict[0] == 'spam'):
    print(sp2, '==> spam mail')
else:
    print(sp2, '==> ham mail')
# Out:
# XXXMobileMovieClub To use your credit click the WAP link in the next txt message or click here http wap xxxmobilemovieclub com n QJKGIGHJJGCBL ==> spam mail

# %% [markdown]
# ### 모델 저장

# %%
import pickle
import joblib

# %%
tfidf_fit = tfidf.fit(spam_df['v2'])
tfidf_fit
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.float64'>, encoding='utf-8',
#                 input='content', lowercase=True, max_df=1.0, max_features=None,
#                 min_df=5, ngram_range=(1, 1), norm='l2', preprocessor=None,
#                 smooth_idf=True, stop_words='english', strip_accents=None,
#                 sublinear_tf=False, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, use_idf=True, vocabulary=None)

# %%
saved_model = pickle.dumps(SA_lr)

# %%
lr_from_pickle = pickle.loads(saved_model)
lr_from_pickle.predict(sp_tfidf[0])
# Out:
# array(['spam'], dtype=object)

# %%
joblib.dump(SA_lr, 'spam_SA_lr.pkl')
# Out:
# ['spam_SA_lr.pkl']

# %%
lr_from_joblib = joblib.load('spam_SA_lr.pkl')
lr_from_joblib
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=0, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
lr_from_joblib.predict(sp_tfidf[0])
# Out:
# array(['spam'], dtype=object)
