# %%
# !pip install tensorflow==2.7.0
# Out:
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-cp37-none-any.whl size=4835 sha256=ba8c451969770794f5164af18902af5fc699b12675b6ea9abae9a0ae26dbf908
#   Stored in directory: C:\Users\hi\AppData\Local\pip\Cache\wheels\7c\06\54\bc84598ba1daf8f970247f550b175aaaee85f68b4b0c5ab2c6
# Successfully built termcolor
# ...
#   Found existing installation: Werkzeug 0.16.0
#     Uninstalling Werkzeug-0.16.0:
#       Successfully uninstalled Werkzeug-0.16.0
#   Found existing installation: importlib-metadata 0.23
#     Uninstalling importlib-metadata-0.23:
#       Successfully uninstalled importlib-metadata-0.23
# ...
