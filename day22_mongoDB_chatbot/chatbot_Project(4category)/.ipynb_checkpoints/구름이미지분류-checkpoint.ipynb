# %%
import warnings
warnings.filterwarnings(action='ignore')
import os.path
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns
import PIL
import pathlib

from glob import glob
from tensorflow.keras import layers
from tensorflow import keras
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,accuracy_score
from keras.models import load_model

# %%
from matplotlib import rc
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm  # 폰트 관련 용도
 
# %config InlineBackend.figure_format = 'retina'
# 디렉토리 및 파일 이름에 맞추어 변경
font_location = 'C:/Windows/Fonts/malgun.ttf'#윈도우안에있는 폰트파일주소.
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
print(os.getcwd())
# Out:
# C:\Users\hi\Anaconda3\jupiter\day22_mongoDB_chatbot\chatbot_Project(4category)

# %%
# 파일 경로 재설정
base_dir = os.chdir("C:/Users/hi/Anaconda3/jupiter/day22_mongoDB_chatbot/chatbot_Project(4category)/cloud_data/train/train_all")
print(os.getcwd())
# Out:
# C:\Users\hi\Anaconda3\jupiter\day22_mongoDB_chatbot\chatbot_Project(4category)\cloud_data\train\train_all

# %%
print(os.getcwd())
# Out:
# C:\Users\hi\Anaconda3\jupiter\day22_mongoDB_chatbot\chatbot_Project(4category)\cloud_data\train\train_all

# %%
data_dir = pathlib.Path(os.getcwd())

# %%
image_count = len(list(data_dir.glob('*/*.jpg')))
print(image_count)
# Out:
# 2323

# %%
Ac = list(data_dir.glob('Ac/*'))
PIL.Image.open(str(Ac[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1C8AD66E888>

# %%
PIL.Image.open(str(Ac[1]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1C8AD492108>

# %%
St = list(data_dir.glob('St/*'))
PIL.Image.open(str(St[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1C8AD73ED08>

# %%
Ci = list(data_dir.glob('Ci/*'))
PIL.Image.open(str(Ci[0]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1C8AD6987C8>

# %% [markdown]
# # 데이터 세트 만들기

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# # 전체 이미지에서 훈련 이미지 80% 검증 이미지 20%로 나누기

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2323 files belonging to 11 classes.
# Using 1859 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 2323 files belonging to 11 classes.
# Using 464 files for validation.

# %% [markdown]
# # class_name 재설정하기

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['Ac', 'As', 'Cb', 'Cc', 'Ci', 'Cs', 'Ct', 'Cu', 'Ns', 'Sc', 'St']

# %%
class_names = ['고적운(altocumulus, Ac)', '고도층(altostratus, As)', '적란운(cumulonimbus, Cb)',
               '권적운(cirrocumulus, Cc)', '권운(cirrus, Ci)', '권층운(cirrostratus, Cs)', 
               '비행운(contrail, Ct)', '적운(cumulus, Cu)', '후광층(nimbostratus, Ns)',
               '성층적운(stratocumulus, Sc)', '충운(stratus, St)'
               ]
print(class_names)
# Out:
# ['고적운(altocumulus, Ac)', '고도층(altostratus, As)', '적란운(cumulonimbus, Cb)', '권적운(cirrocumulus, Cc)', '권운(cirrus, Ci)', '권층운(cirrostratus, Cs)', '비행운(contrail, Ct)', '적운(cumulus, Cu)', '후광층(nimbostratus, Ns)', '성층적운(stratocumulus, Sc)', '충운(stratus, St)']

# %% [markdown]
# # 데이터 세트 시각화하기

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [markdown]
# # 데이터 세트 구성하기

# %%
# tf.data.experimental.AUTOTUNE: tf.data 런타임이 실행 시에 동적으로 값을 조정
AUTOTUNE = tf.data.experimental.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# # 데이터 표준화하기

# %%
normalization_layer = layers.experimental.preprocessing.Rescaling(1/255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0019729785 0.9217139

# %% [markdown]
# # 모델 만들기

# %%
num_classes = 11

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# # 모델 컴파일하기

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# # 모델 요약

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 3,990,059
# Trainable params: 3,990,059
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 모델훈련

# %%
epochs=30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 59/59 [==============================] - 20s 327ms/step - loss: 2.2581 - accuracy: 0.1850 - val_loss: 2.1668 - val_accuracy: 0.2888
# Epoch 2/30
# 59/59 [==============================] - 19s 316ms/step - loss: 2.0408 - accuracy: 0.2926 - val_loss: 2.0753 - val_accuracy: 0.2823
# Epoch 3/30
# 59/59 [==============================] - 19s 319ms/step - loss: 1.8531 - accuracy: 0.3588 - val_loss: 2.0518 - val_accuracy: 0.3254
# Epoch 4/30
# 59/59 [==============================] - 19s 317ms/step - loss: 1.6523 - accuracy: 0.4250 - val_loss: 2.0039 - val_accuracy: 0.3341
# Epoch 5/30
# 59/59 [==============================] - 19s 315ms/step - loss: 1.4047 - accuracy: 0.5250 - val_loss: 2.0539 - val_accuracy: 0.3276
# Epoch 6/30
# 59/59 [==============================] - 19s 316ms/step - loss: 1.1307 - accuracy: 0.6143 - val_loss: 2.2993 - val_accuracy: 0.3125
# Epoch 7/30
# 59/59 [==============================] - 19s 317ms/step - loss: 0.8820 - accuracy: 0.7111 - val_loss: 2.5712 - val_accuracy: 0.3297
# Epoch 8/30
# 59/59 [==============================] - 19s 318ms/step - loss: 0.6574 - accuracy: 0.7891 - val_loss: 2.9172 - val_accuracy: 0.3060
# Epoch 9/30
# 59/59 [==============================] - 19s 317ms/step - loss: 0.5288 - accuracy: 0.8451 - val_loss: 3.1420 - val_accuracy: 0.3233
# Epoch 10/30
# 59/59 [==============================] - 19s 325ms/step - loss: 0.4011 - accuracy: 0.8892 - val_loss: 3.6778 - val_accuracy: 0.3578
# Epoch 11/30
# 59/59 [==============================] - 19s 317ms/step - loss: 0.3956 - accuracy: 0.8924 - val_loss: 3.5433 - val_accuracy: 0.2909
# Epoch 12/30
# 59/59 [==============================] - 19s 316ms/step - loss: 0.3225 - accuracy: 0.9155 - val_loss: 3.5792 - val_accuracy: 0.3190
# Epoch 13/30
# 59/59 [==============================] - 19s 317ms/step - loss: 0.2888 - accuracy: 0.9252 - val_loss: 3.2301 - val_accuracy: 0.2759
# Epoch 14/30
# 59/59 [==============================] - 20s 331ms/step - loss: 0.2870 - accuracy: 0.9279 - val_loss: 3.8171 - val_accuracy: 0.3017
# Epoch 15/30
# 59/59 [==============================] - 20s 336ms/step - loss: 0.2525 - accuracy: 0.9333 - val_loss: 3.7324 - val_accuracy: 0.3082
# Epoch 16/30
# 59/59 [==============================] - 20s 345ms/step - loss: 0.2447 - accuracy: 0.9408 - val_loss: 3.6899 - val_accuracy: 0.2974
# Epoch 17/30
# 59/59 [==============================] - 20s 340ms/step - loss: 0.2260 - accuracy: 0.9462 - val_loss: 3.9760 - val_accuracy: 0.3125
# Epoch 18/30
# 59/59 [==============================] - 20s 339ms/step - loss: 0.1975 - accuracy: 0.9457 - val_loss: 3.8884 - val_accuracy: 0.3060
# Epoch 19/30
# 59/59 [==============================] - 19s 319ms/step - loss: 0.1898 - accuracy: 0.9462 - val_loss: 3.9548 - val_accuracy: 0.3060
# Epoch 20/30
# 59/59 [==============================] - 20s 341ms/step - loss: 0.1804 - accuracy: 0.9516 - val_loss: 3.7059 - val_accuracy: 0.2759
# Epoch 21/30
# 59/59 [==============================] - 20s 334ms/step - loss: 0.1507 - accuracy: 0.9543 - val_loss: 4.1489 - val_accuracy: 0.2931
# Epoch 22/30
# 59/59 [==============================] - 20s 341ms/step - loss: 0.1454 - accuracy: 0.9575 - val_loss: 4.1946 - val_accuracy: 0.3039
# Epoch 23/30
# 59/59 [==============================] - 20s 337ms/step - loss: 0.1142 - accuracy: 0.9634 - val_loss: 4.4346 - val_accuracy: 0.3103
# Epoch 24/30
# 59/59 [==============================] - 20s 347ms/step - loss: 0.1521 - accuracy: 0.9548 - val_loss: 3.9482 - val_accuracy: 0.3147
# Epoch 25/30
# 59/59 [==============================] - 20s 346ms/step - loss: 0.1253 - accuracy: 0.9597 - val_loss: 3.9790 - val_accuracy: 0.3168
# Epoch 26/30
# 59/59 [==============================] - 20s 335ms/step - loss: 0.1203 - accuracy: 0.9613 - val_loss: 4.0871 - val_accuracy: 0.3060
# Epoch 27/30
# 59/59 [==============================] - 20s 332ms/step - loss: 0.1177 - accuracy: 0.9586 - val_loss: 4.0552 - val_accuracy: 0.2823
# Epoch 28/30
# 59/59 [==============================] - 20s 331ms/step - loss: 0.1301 - accuracy: 0.9575 - val_loss: 3.8111 - val_accuracy: 0.2888
# Epoch 29/30
# 59/59 [==============================] - 19s 325ms/step - loss: 0.1269 - accuracy: 0.9564 - val_loss: 3.9833 - val_accuracy: 0.3017
# Epoch 30/30
# 59/59 [==============================] - 20s 341ms/step - loss: 0.1135 - accuracy: 0.9591 - val_loss: 4.2605 - val_accuracy: 0.3082

# %% [markdown]
# # 훈련결과시작하기

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss=history.history['loss']
val_loss=history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # 데이터 증강

# %%
data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(img_height, 
                                                              img_width,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),
    layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

# %% [markdown]
# # 증강한 데이터 시각화

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %%
# 모델 재구성

# %%
model2 = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# # 재구성한 모델 컴파일 및 훈련

# %%
model2.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 180, 180, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 180, 180, 16)      448
#
#  max_pooling2d_3 (MaxPooling  (None, 90, 90, 16)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_4 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_5 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  dropout (Dropout)           (None, 22, 22, 64)        0
#
#  flatten_1 (Flatten)         (None, 30976)             0
#
#  dense_2 (Dense)             (None, 128)               3965056
#
#  dense_3 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 3,990,059
# Trainable params: 3,990,059
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=30
history2 = model2.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 59/59 [==============================] - 27s 449ms/step - loss: 2.3069 - accuracy: 0.1824 - val_loss: 2.2009 - val_accuracy: 0.2134
# Epoch 2/30
# 59/59 [==============================] - 25s 423ms/step - loss: 2.1123 - accuracy: 0.2571 - val_loss: 2.1252 - val_accuracy: 0.2823
# Epoch 3/30
# 59/59 [==============================] - 25s 425ms/step - loss: 2.0287 - accuracy: 0.2856 - val_loss: 2.1302 - val_accuracy: 0.2694
# Epoch 4/30
# 59/59 [==============================] - 24s 409ms/step - loss: 1.9578 - accuracy: 0.3082 - val_loss: 2.0684 - val_accuracy: 0.3103
# Epoch 5/30
# 59/59 [==============================] - 26s 439ms/step - loss: 1.9324 - accuracy: 0.3029 - val_loss: 2.0553 - val_accuracy: 0.3039
# Epoch 6/30
# 59/59 [==============================] - 25s 422ms/step - loss: 1.9061 - accuracy: 0.3287 - val_loss: 2.0290 - val_accuracy: 0.3039
# Epoch 7/30
# 59/59 [==============================] - 24s 414ms/step - loss: 1.8550 - accuracy: 0.3491 - val_loss: 2.0049 - val_accuracy: 0.3621
# Epoch 8/30
# 59/59 [==============================] - 25s 421ms/step - loss: 1.8306 - accuracy: 0.3599 - val_loss: 2.0390 - val_accuracy: 0.3319
# Epoch 9/30
# 59/59 [==============================] - 27s 460ms/step - loss: 1.7793 - accuracy: 0.3696 - val_loss: 2.0004 - val_accuracy: 0.3599
# Epoch 10/30
# 59/59 [==============================] - 26s 434ms/step - loss: 1.7604 - accuracy: 0.3771 - val_loss: 1.9863 - val_accuracy: 0.3297
# Epoch 11/30
# 59/59 [==============================] - 24s 406ms/step - loss: 1.7264 - accuracy: 0.3868 - val_loss: 2.0273 - val_accuracy: 0.3211
# Epoch 12/30
# 59/59 [==============================] - 22s 376ms/step - loss: 1.6966 - accuracy: 0.3954 - val_loss: 2.0210 - val_accuracy: 0.3513
# Epoch 13/30
# 59/59 [==============================] - 26s 446ms/step - loss: 1.6629 - accuracy: 0.4051 - val_loss: 1.9521 - val_accuracy: 0.3491
# Epoch 14/30
# 59/59 [==============================] - 25s 419ms/step - loss: 1.6343 - accuracy: 0.4120 - val_loss: 1.9746 - val_accuracy: 0.3513
# Epoch 15/30
# 59/59 [==============================] - 24s 402ms/step - loss: 1.6210 - accuracy: 0.4083 - val_loss: 2.0076 - val_accuracy: 0.3513
# Epoch 16/30
# 59/59 [==============================] - 23s 396ms/step - loss: 1.5752 - accuracy: 0.4400 - val_loss: 2.0336 - val_accuracy: 0.3836
# Epoch 17/30
# 59/59 [==============================] - 24s 413ms/step - loss: 1.5595 - accuracy: 0.4545 - val_loss: 1.9622 - val_accuracy: 0.3599
# Epoch 18/30
# 59/59 [==============================] - 23s 390ms/step - loss: 1.5797 - accuracy: 0.4325 - val_loss: 1.9337 - val_accuracy: 0.3728
# Epoch 19/30
# 59/59 [==============================] - 24s 399ms/step - loss: 1.4871 - accuracy: 0.4820 - val_loss: 2.0716 - val_accuracy: 0.3750
# Epoch 20/30
# 59/59 [==============================] - 26s 448ms/step - loss: 1.4838 - accuracy: 0.4653 - val_loss: 2.0220 - val_accuracy: 0.3491
# Epoch 21/30
# 59/59 [==============================] - 26s 441ms/step - loss: 1.4855 - accuracy: 0.4788 - val_loss: 2.0871 - val_accuracy: 0.3685
# Epoch 22/30
# 59/59 [==============================] - 26s 444ms/step - loss: 1.4015 - accuracy: 0.4976 - val_loss: 2.1091 - val_accuracy: 0.3793
# Epoch 23/30
# 59/59 [==============================] - 24s 411ms/step - loss: 1.3772 - accuracy: 0.5143 - val_loss: 2.1952 - val_accuracy: 0.3384
# Epoch 24/30
# 59/59 [==============================] - 25s 426ms/step - loss: 1.3438 - accuracy: 0.5245 - val_loss: 2.1924 - val_accuracy: 0.3599
# Epoch 25/30
# 59/59 [==============================] - 24s 411ms/step - loss: 1.3219 - accuracy: 0.5320 - val_loss: 2.1551 - val_accuracy: 0.3513
# Epoch 26/30
# 59/59 [==============================] - 24s 405ms/step - loss: 1.3120 - accuracy: 0.5336 - val_loss: 2.2780 - val_accuracy: 0.3642
# Epoch 27/30
# 59/59 [==============================] - 23s 395ms/step - loss: 1.2835 - accuracy: 0.5530 - val_loss: 2.0965 - val_accuracy: 0.3836
# Epoch 28/30
# 59/59 [==============================] - 25s 420ms/step - loss: 1.2630 - accuracy: 0.5578 - val_loss: 2.1684 - val_accuracy: 0.3707
# Epoch 29/30
# 59/59 [==============================] - 24s 414ms/step - loss: 1.2266 - accuracy: 0.5611 - val_loss: 2.4213 - val_accuracy: 0.3362
# Epoch 30/30
# 59/59 [==============================] - 24s 414ms/step - loss: 1.2014 - accuracy: 0.5707 - val_loss: 2.4416 - val_accuracy: 0.3707

# %% [markdown]
# # 훈련 결과 시각화

# %%
val_acc2 = history2.history['val_accuracy']

loss2 = history2.history['loss']
val_loss2 = history2.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # 모델 저장

# %%
model.save('C:/Users/hi/Desktop/DeepLearning/data/cloud_model.h7')
# Out:
# INFO:tensorflow:Assets written to: C:/Users/hi/Desktop/DeepLearning/data/cloud_model.h7\assets

# %% [markdown]
# # 새로운 데이터 예측

# %%
change_dir = os.chdir("C:/Users/hi/Anaconda3/jupiter/day22_mongoDB_chatbot/chatbot_Project(4category)/cloud_data/test/")

# %%
test_dir = pathlib.Path(os.getcwd())

# %%
test_dir
# Out:
# WindowsPath('C:/Users/hi/Anaconda3/jupiter/day22_mongoDB_chatbot/chatbot_Project(4category)/cloud_data/test')

# %%
test_imagelist = list(test_dir.glob('*'))

# %%
PIL.Image.open(str(test_imagelist[200]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=400x400 at 0x1C88CCAF988>

# %%
img = keras.preprocessing.image.load_img(
    test_imagelist[200], target_size=(img_height, img_width)
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0) # Create a batch

model = load_model('C:/Users/hi/Desktop/DeepLearning/data/cloud_model.h7')

predictions = model2.predict(img_array)
score = tf.nn.softmax(predictions[0])

print(
    "{:.2f}%의 확률로 {}으로 예측됨"
    .format(100 * np.max(score), class_names[np.argmax(score)])
)
# Out:
# 85.59%의 확률로 권층운(cirrostratus, Cs)으로 예측됨
