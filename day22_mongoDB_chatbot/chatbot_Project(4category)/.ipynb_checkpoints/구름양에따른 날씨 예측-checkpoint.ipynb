# %%
import urllib.request
import re
from konlpy.tag import Okt
from tqdm import tqdm
import numpy as np
import pandas as pd
import os
from matplotlib import pyplot as plt
print(os.getcwd())
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import warnings
warnings.filterwarnings(action='ignore')

from tkinter import *
from tkinter.ttk import *
import tkinter.font as font
from tkinter import filedialog
import os
from PIL import ImageTk, Image
import tensorflow as tf
import cv2
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
import numpy as np
from numpy import argmax
import glob
from glob import glob
from keras.models import load_model
from tensorflow.keras.preprocessing.text import text_to_word_sequence
# Out:
# C:\Users\hi\Anaconda3\jupiter\day22_mongoDB_chatbot\chatbot_Project(4category)\cloud_data\train\train_all

# %%
from matplotlib import rc
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm  # 폰트 관련 용도
 
# %config InlineBackend.figure_format = 'retina'

# %%
# 디렉토리 및 파일 이름에 맞추어 변경
font_location = 'C:/Windows/Fonts/malgun.ttf'#윈도우안에있는 폰트파일주소.
font_name = fm.FontProperties(fname=font_location).get_name()
plt.rc('font', family=font_name)

# %%
data_dir = os.chdir(os.getcwd() + "./train_all2 - 복사본/")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-846bdde4e60c> in <module>
# ----> 1 data_dir = os.chdir(os.getcwd() + "./train_all2 - 복사본/")
#
# FileNotFoundError: [WinError 2] 지정된 파일을 찾을 수 없습니다: 'C:\\Users\\hi\\Anaconda3\\jupiter\\day22_mongoDB_chatbot\\chatbot_Project(4category)\\cloud_data\\train\\train_all./train_all2 - 복사본/'

# %%
print(os.getcwd())
# Out:
# C:\Users\hi\Anaconda3\jupiter\day22_mongoDB_chatbot\chatbot_Project(4category)\cloud_data\train\train_all

# %%
data_list = glob('*.jpg')
print('파일의 목록 개수 >> ', len(data_list))
print('파일의 목록 타입 >> ', type(data_list))
# Out:
# 파일의 목록 개수 >>  2323
# 파일의 목록 타입 >>  <class 'list'>

# %% [markdown]
# # string을 특정한 기준에 의해 token으로 끊어 리스트를 리턴
# # ex) Ac.0.jpg => Ac만 추출해서 list에 담아보자

# %%
token = text_to_word_sequence(data_list[0])
token, type(token)
# Out:
# (['ac', '0', '1', 'jpg'], list)

# %%
label2 = []

# %%
for x in data_list[:2323]:
    token = text_to_word_sequence(x)
    label2.append(token[0])
len(label2)
# Out:
# 2323

# %%
# 라벨 인코딩(카테고리형 문자를 숫자로 자동 변환해주는 역할)
from sklearn.preprocessing import LabelEncoder

# %%
encoder = LabelEncoder()
encoder = LabelEncoder()
label3 = encoder.fit_transform(label2)
label3[:5]
# Out:
# array([0, 0, 0, 0, 0], dtype=int64)

# %%
img0 = cv2.imread(data_list[0])
plt.imshow(img0)

# %%
#이미지 shape확인!(가로,세로,칼라)의미
img0.shape
# Out:
# (400, 400, 3)

# %%
data_height = 200
data_width = 200
channel_n = 3#칼라로 맞추기(흑백이면 1)칼라는 rgb3개를 고려해야하기 때문에 3이다.

# %%
## 이미지 표준화(0~1사이로)
## 픽셀은 0~255의 크기를 가지므로 255로 나누어서 
## 표준화를 진행해주자.(0~1사이로표시)
## 2323개의 크기를 다 변경해주세요
img_list = []#크기를 변경하고 나서의 결과를 모아주기 위한 리스트
# 2323개의 이미지 전처리(스케일링)
for x in data_list:
    #픽셀크기가(0~255)이므로 255로 나누자
    scaled_one = cv2.imread(x) / 255
    resized_one = cv2.resize(scaled_one, (data_height, data_width))
#     print('변경 전', scaled_one.shape)
#     print('변경 후', resized_one.shape)    
    img_list.append(resized_one)
len(img_list),img_list[0].shape
# Out:
# (2323, (200, 200, 3))

# %%
img_list[0][0]
# Out:
# array([[0.19313725, 0.18137255, 0.16568627],
#        [0.15686275, 0.13333333, 0.11372549],
#        [0.17745098, 0.13823529, 0.11078431],
#        [0.18137255, 0.14215686, 0.11470588],
#        [0.18627451, 0.15490196, 0.12745098],
#        [0.2       , 0.16470588, 0.14901961],
#        [0.15196078, 0.12843137, 0.10882353],
#        [0.14705882, 0.11960784, 0.10784314],
#        [0.15294118, 0.1254902 , 0.11372549],
#        [0.14705882, 0.11960784, 0.10784314]])

# %%
##data_list : 전체 이미지 목록의 리스트
##읽어온 이미지 목록을 넣으면 라벨링/이미지 스케일링/리사이징해서
##우리가 원하는 이미지 데이터를 만들자.
def make_file(data_height, data_width, channel_n, data_list_n):#len(data_list)=data_list_n
    ## 라벨링한 결과 넣어줄 리스트 필요
    label = []
    ## 4차원으로 만들어줄 4차원 리스트 필요
    images = np.zeros((data_list_n, data_height, data_width, channel_n))
    ## 이미지 리스트에서 하나씩 꺼내서 라벨링, 스케일링, 리사이징하자
    for i, image in enumerate(data_list):#i가 1씩증가,data_list에 이미지 목록 다 들어있음
        
        ## 라벨링:
        tokens = text_to_word_sequence(image)#이미지를 토큰으로 끊어주자(이런식으로)
        label.append(tokens[0])#0번째 토큰
        
        ## 읽어서, 스케일링, 리사이징해서
        image2 = cv2.imread(image)
        image3 = cv2.resize(image2,(data_height, data_width)) / 255
        
        ## 4차원 리스트에 하나씩 끼자
        images[i, :, :, :] = image3
    label2 = np.array(label)
    return label2, images

# %%
labels, images = make_file(data_height, data_width, channel_n, 2323)#2323개의 이미지

# %%
#labels에 어떤 옷인지에 대한 카테고리 토큰만 담김
labels
# Out:
# array(['ac', 'ac', 'ac', ..., 'st', 'st', 'st'], dtype='<U2')

# %%
#2323개 1차원의 shape을 가짐['blouse', 'blouse', 'jacket', ..., 'tshirt']
labels.shape
# Out:
# (2323,)

# %%
items = label2
#카테고리를 라벨인코더를 통해 수치화 시켜보자.
encoder = LabelEncoder()
label = encoder.fit_transform(items)
label, len(label)
# Out:
# (array([ 0,  0,  0, ..., 10, 10, 10], dtype=int64), 2323)

# %%
encoder.classes_
# Out:
# array(['ac', 'as', 'cb', 'cc', 'ci', 'cs', 'ct', 'cu', 'ns', 'sc', 'st'],
#       dtype='<U2')

# %% [markdown]
# # train, test 데이터 나누기

# %%
from sklearn.model_selection import train_test_split

# %%
x = images
y = label

X_train, X_test, y_train, y_test = train_test_split(x, 
                                                    y, 
                                                    test_size= 0.2,
                                                    random_state=55
                                                   )
print(X_train.shape, X_test.shape)
# Out:
# (1858, 200, 200, 3) (465, 200, 200, 3)

# %%
## 딥러닝 모델을 만들어보자.
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import datasets, layers, models

# %% [markdown]
# # 레이어 쌓기

# %%
model = models.Sequential()
## 특성추출 레이어를 쌓아준다.
model.add(Conv2D(32,(3, 3), activation='relu', input_shape=(data_height, data_width, 3)))
model.add(MaxPool2D((2,2)))#최대값으로 요약
model.add(Conv2D(32,(3, 3), activation='relu', input_shape=(data_height, data_width, 3)))
model.add(MaxPool2D((2,2)))#최대값으로 요약
model.add(Conv2D(64,(3, 3), activation='relu'))
model.add(MaxPool2D((2,2)))#최대값으로 요약

## 딥러닝 학습 레이어를 쌓아준다.
## 입력 -- 히든 -- 출력 순서대로 쌓아준다.
## 입력(1개)--1차원이어야함
model.add(Flatten())#이미지 데이터를 1차원으로 만들어주는 객체
## 히든(N개)
model.add(Dense(128, activation='relu'))
model.add(Dropout(rate=0.5))#오버피팅 되는 것을 막기 위해 공부한거 드랍아웃 해줌
model.add(Dense(64, activation='relu'))
model.add(Dropout(rate=0.5))#오버피팅 되는 것을 막기 위해 공부한거 드랍아웃 해줌
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dropout(rate=0.5))#오버피팅 되는 것을 막기 위해 공부한거 드랍아웃 해줌

## 출력(1개)--딥러닝으로 하는 학습의 종류에 따라 다르게 써주어야 함!
## 이진 분류인경우(1, sigmoid)
## 다중 분류인경우(n, softmax)
## 회귀인 경우(1, linear)
model.add(Dense(11, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dense (Dense)               (None, 128)               4333696
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_4 (Dense)             (None, 11)                187
#
# =================================================================
# Total params: 4,373,387
# Trainable params: 4,373,387
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 모델의 설정값 지정
## 1. 기울기 찾는데 최적의 방법 설정(optimizer)
## 2. 특정한 가중치를 가지는 경우 오차를 계산하는 방법 설정(loss)
##    회귀인 경우: mae
##    분류인 경우: 이진=> binary_crossentropy,
##    다중분류인 경우=> sparse_categorical_crossentropy
## 3. fit시킬 때 fit시키는 상황이 순서대로 프린트되는데 출력되는 항목 설정(metrics)
model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %% [markdown]
# # 에포크 돌리기

# %%
## 공부시키자
# epoch마다 train의 loss,acc 뿐만아니라 test의 loss,acc도 알고싶어
# fit함수안에 validation_data=(X_test, y_test)를 넣어 돌려보자.
# 조기종료(earlyStopping) : 
# epoch를 실행할 때 최적의 acc인 경우, 더이상 epoch를 수행하지 않아도 되도록 설정
# 모델저장(checkPoint):
# 최적의 acc인 경우의 가중치를 자동으로 모델파일로 저장하게 설정
# 특정한 상황을 기다렸다가 특정한 처리를 하고자 하는 경우(콜백함수)
# 1)객체를 만들어주고, fit(callbacks = [객체])
es = EarlyStopping(patience=20, restore_best_weights=True)
cp = ModelCheckpoint('best_cnn_1.h7')
cnn_history = model.fit(
    X_train,
    y_train,
    batch_size=50,
    epochs=60,
    validation_data=(X_test, y_test),
    callbacks=[es, cp],
    verbose=2
)
# Out:
# Epoch 1/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 2.4113 - accuracy: 0.0974 - val_loss: 2.3865 - val_accuracy: 0.1161 - 33s/epoch - 1s/step
# Epoch 2/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3843 - accuracy: 0.1324 - val_loss: 2.3755 - val_accuracy: 0.1290 - 32s/epoch - 1s/step
# Epoch 3/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3844 - accuracy: 0.1453 - val_loss: 2.3741 - val_accuracy: 0.1914 - 32s/epoch - 1s/step
# Epoch 4/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3773 - accuracy: 0.1372 - val_loss: 2.3662 - val_accuracy: 0.1892 - 32s/epoch - 1s/step
# Epoch 5/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3727 - accuracy: 0.1410 - val_loss: 2.3405 - val_accuracy: 0.2000 - 32s/epoch - 1s/step
# Epoch 6/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3636 - accuracy: 0.1496 - val_loss: 2.3172 - val_accuracy: 0.2301 - 32s/epoch - 1s/step
# Epoch 7/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 2.3482 - accuracy: 0.1625 - val_loss: 2.3244 - val_accuracy: 0.2280 - 33s/epoch - 1s/step
# Epoch 8/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 36s - loss: 2.3473 - accuracy: 0.1663 - val_loss: 2.3189 - val_accuracy: 0.2258 - 36s/epoch - 1s/step
# Epoch 9/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 34s - loss: 2.3475 - accuracy: 0.1561 - val_loss: 2.3346 - val_accuracy: 0.2366 - 34s/epoch - 1s/step
# Epoch 10/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3338 - accuracy: 0.1652 - val_loss: 2.3010 - val_accuracy: 0.2366 - 32s/epoch - 1s/step
# Epoch 11/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3111 - accuracy: 0.1760 - val_loss: 2.2862 - val_accuracy: 0.2344 - 32s/epoch - 1s/step
# Epoch 12/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3012 - accuracy: 0.1749 - val_loss: 2.2758 - val_accuracy: 0.2387 - 32s/epoch - 1s/step
# Epoch 13/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.3011 - accuracy: 0.1760 - val_loss: 2.2479 - val_accuracy: 0.2538 - 32s/epoch - 1s/step
# Epoch 14/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 2.2861 - accuracy: 0.1738 - val_loss: 2.2236 - val_accuracy: 0.2387 - 33s/epoch - 1s/step
# Epoch 15/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.2642 - accuracy: 0.1755 - val_loss: 2.2121 - val_accuracy: 0.2344 - 32s/epoch - 1s/step
# Epoch 16/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.2746 - accuracy: 0.1884 - val_loss: 2.1958 - val_accuracy: 0.2559 - 32s/epoch - 1s/step
# Epoch 17/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.2413 - accuracy: 0.1814 - val_loss: 2.1748 - val_accuracy: 0.2839 - 32s/epoch - 1s/step
# Epoch 18/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.2377 - accuracy: 0.1911 - val_loss: 2.1717 - val_accuracy: 0.2946 - 32s/epoch - 1s/step
# Epoch 19/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.2250 - accuracy: 0.1948 - val_loss: 2.1515 - val_accuracy: 0.2495 - 32s/epoch - 1s/step
# Epoch 20/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.1967 - accuracy: 0.2045 - val_loss: 2.1492 - val_accuracy: 0.2667 - 32s/epoch - 1s/step
# Epoch 21/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 2.1955 - accuracy: 0.1975 - val_loss: 2.1552 - val_accuracy: 0.2817 - 33s/epoch - 1s/step
# Epoch 22/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 2.1873 - accuracy: 0.2067 - val_loss: 2.1156 - val_accuracy: 0.2710 - 33s/epoch - 1s/step
# Epoch 23/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 2.1659 - accuracy: 0.2121 - val_loss: 2.0873 - val_accuracy: 0.2753 - 33s/epoch - 1s/step
# Epoch 24/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 35s - loss: 2.1616 - accuracy: 0.2088 - val_loss: 2.0933 - val_accuracy: 0.3032 - 35s/epoch - 1s/step
# Epoch 25/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 36s - loss: 2.1423 - accuracy: 0.2153 - val_loss: 2.1130 - val_accuracy: 0.3161 - 36s/epoch - 1s/step
# Epoch 26/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 38s - loss: 2.1220 - accuracy: 0.2282 - val_loss: 2.1114 - val_accuracy: 0.3183 - 38s/epoch - 2s/step
# Epoch 27/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 34s - loss: 2.1247 - accuracy: 0.2244 - val_loss: 2.0733 - val_accuracy: 0.3312 - 34s/epoch - 1s/step
# Epoch 28/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 2.0935 - accuracy: 0.2336 - val_loss: 2.0825 - val_accuracy: 0.3097 - 33s/epoch - 1s/step
# Epoch 29/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.0479 - accuracy: 0.2605 - val_loss: 2.0786 - val_accuracy: 0.3333 - 32s/epoch - 1s/step
# Epoch 30/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.0413 - accuracy: 0.2454 - val_loss: 2.0591 - val_accuracy: 0.3247 - 32s/epoch - 1s/step
# Epoch 31/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 2.0278 - accuracy: 0.2540 - val_loss: 2.0832 - val_accuracy: 0.3333 - 32s/epoch - 1s/step
# Epoch 32/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.9830 - accuracy: 0.2707 - val_loss: 2.0391 - val_accuracy: 0.3333 - 32s/epoch - 1s/step
# Epoch 33/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 1.9638 - accuracy: 0.2809 - val_loss: 2.0526 - val_accuracy: 0.3398 - 33s/epoch - 1s/step
# Epoch 34/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.9361 - accuracy: 0.2842 - val_loss: 2.0638 - val_accuracy: 0.3505 - 32s/epoch - 1s/step
# Epoch 35/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 1.9200 - accuracy: 0.2885 - val_loss: 2.0785 - val_accuracy: 0.3204 - 33s/epoch - 1s/step
# Epoch 36/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.8910 - accuracy: 0.3062 - val_loss: 2.0675 - val_accuracy: 0.3419 - 32s/epoch - 1s/step
# Epoch 37/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.9166 - accuracy: 0.2960 - val_loss: 2.0698 - val_accuracy: 0.3376 - 32s/epoch - 1s/step
# Epoch 38/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.8403 - accuracy: 0.3197 - val_loss: 2.1036 - val_accuracy: 0.3376 - 32s/epoch - 1s/step
# Epoch 39/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.8274 - accuracy: 0.3219 - val_loss: 2.0713 - val_accuracy: 0.3011 - 32s/epoch - 1s/step
# Epoch 40/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.7785 - accuracy: 0.3315 - val_loss: 2.0749 - val_accuracy: 0.3355 - 32s/epoch - 1s/step
# Epoch 41/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.7500 - accuracy: 0.3407 - val_loss: 2.1702 - val_accuracy: 0.3333 - 32s/epoch - 1s/step
# Epoch 42/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.7345 - accuracy: 0.3525 - val_loss: 2.1741 - val_accuracy: 0.3269 - 32s/epoch - 1s/step
# Epoch 43/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.7224 - accuracy: 0.3493 - val_loss: 2.1380 - val_accuracy: 0.3441 - 32s/epoch - 1s/step
# Epoch 44/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.7181 - accuracy: 0.3665 - val_loss: 2.1489 - val_accuracy: 0.2946 - 32s/epoch - 1s/step
# Epoch 45/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 33s - loss: 1.6730 - accuracy: 0.3719 - val_loss: 2.2639 - val_accuracy: 0.3161 - 33s/epoch - 1s/step
# Epoch 46/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.6487 - accuracy: 0.3671 - val_loss: 2.3532 - val_accuracy: 0.3247 - 32s/epoch - 1s/step
# Epoch 47/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.6485 - accuracy: 0.3800 - val_loss: 2.2585 - val_accuracy: 0.3355 - 32s/epoch - 1s/step
# Epoch 48/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 34s - loss: 1.6023 - accuracy: 0.4107 - val_loss: 2.2611 - val_accuracy: 0.3269 - 34s/epoch - 1s/step
# Epoch 49/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 34s - loss: 1.5702 - accuracy: 0.4031 - val_loss: 2.2741 - val_accuracy: 0.3312 - 34s/epoch - 1s/step
# Epoch 50/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 34s - loss: 1.5615 - accuracy: 0.3956 - val_loss: 2.3816 - val_accuracy: 0.3097 - 34s/epoch - 1s/step
# Epoch 51/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.5555 - accuracy: 0.4026 - val_loss: 2.4133 - val_accuracy: 0.3226 - 32s/epoch - 1s/step
# Epoch 52/60
# INFO:tensorflow:Assets written to: best_cnn_1.h7\assets
# 24/24 - 32s - loss: 1.5510 - accuracy: 0.4225 - val_loss: 2.4232 - val_accuracy: 0.3140 - 32s/epoch - 1s/step

# %%
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1) ## 1행2열의 도표, 1열
plt.plot(cnn_history.history['accuracy'])
plt.plot(cnn_history.history['val_accuracy'])
plt.title('model acc.')
plt.xlabel('epoch')
plt.ylabel('acc')
plt.legend(['train_acc','test_acc'])

plt.subplot(1, 2, 2) ## 1행2열의 도표, 2열
plt.plot(cnn_history.history['loss'])
plt.plot(cnn_history.history['val_loss'])
plt.title('model loss')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train_loss','test_loss'])
